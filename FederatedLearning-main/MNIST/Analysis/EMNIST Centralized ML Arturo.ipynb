# %% [markdown]
# ## Cloud Computing for Distributed Big Data Applications Option : Centralized Machine Learning

# %% [markdown]
# #### The goal of this lab is to get you familiar with the basics of machine learning.
#
# #### You will be asked to train an ML model for a relatively simple dataset 'MNIST' using the torch package

# %%
## import the package

import torch

# %%
# Out:
# 112800

# %%
from IPython import display
from base64 import b64decode
display.Image(b64decode(base64_data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e0fe462b7187> in <module>()
#       1 from IPython import display
#       2 from base64 import b64decode
# ----> 3 display.Image(b64decode(base64_data))
#
# NameError: name 'base64_data' is not defined

# %% [markdown]
# See the documentation
# https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html

# %% [markdown]
# #### Below is a potentially good model architecture to start with.
# ![](model_architecture.jpeg)

# %%
## create the model 
from torch import nn

input_size = 28*28
output_size = 27


class EmnistModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size = 3, padding = 1),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size = 3, padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), #64*14*14

            nn.Conv2d(64, 128, kernel_size = 3, padding = 1),
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size = 3, padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), #256*7*7

            nn.Flatten(),
            nn.Linear(256*7*7, 1024),
            nn.ReLU(),
            nn.Linear(1024, 256),
            nn.ReLU(),
            nn.Linear(256, 27)
        )
        
    def forward(self, xb):
        return self.network(xb)
    
    def training_step(self, batch):
        images, label = batch
        labels = to_device(torch.tensor([x-1 for x in label]), device)
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, label = batch
        labels = to_device(torch.tensor([x-1 for x in label]), device)
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss, 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], val_loss: {:.4f}, val_acc: {:.4f}".format(epoch, result['val_loss'], result['val_acc']))

# %% [markdown]
# See Documentation https://pytorch.org/vision/stable/datasets.html

# %% [markdown]
# ##### The MNIST dataset is  a database of handwritten digits. it has a training set of 60,000 examples, and a test set of 10,000 examples.  The digits have been size-normalized and centered in a fixed-size image.
#
# ##### In the next two cells, you are asked to first : load both the training and test set of MNIST while appllying  the appropriate transformations & second : take a closer look at the dataset by checking the images' shape, the label & displaying some images ( Matplolib library is an option for that)

# %%
## Prepare Dataset
from torchvision import datasets, transforms

transform = transforms.Compose(
[transforms.ToTensor(),
transforms.Normalize((0.1307,), (0.3081,))])

train_dataset = datasets.EMNIST(root='data', split = 'letters', train = True, transform = transform, download = True)
test_dataset = datasets.EMNIST(root='data', split = 'letters', train= False, transform = transform)

def get_dataset():  
    """ Returns train and test datasets for MNIST
        Data is normalized using (0.1307,), (0.3081,)
    """
    
    return train_dataset, test_dataset
  
len(train_dataset)
# Out:
# Downloading https://www.itl.nist.gov/iaui/vip/cs_links/EMNIST/gzip.zip to data/EMNIST/raw/gzip.zip
#   0%|          | 0/561753746 [00:00<?, ?it/s]
# Extracting data/EMNIST/raw/gzip.zip to data/EMNIST/raw
# 124800

# %%
#dataloader

from torch.utils.data import DataLoader

batch_size = 128

train_load = DataLoader(train_dataset, batch_size, shuffle=True, num_workers=2, pin_memory=True)
val_load = DataLoader(test_dataset, batch_size, num_workers=2, pin_memory=True)

# %%
## Display Images 
import matplotlib.pyplot as plt
plt.imshow(train_dataset.data[0], cmap='gray')
plt.title('%i' % train_dataset.targets[0])
plt.show()

# %%
figure = plt.figure(figsize=(10, 8))
cols, rows = 5, 5
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(train_dataset), size=(1,)).item()
    img, label = train_dataset[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(label)
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
#GPU

def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_load = DeviceDataLoader(train_load, device)
val_load = DeviceDataLoader(val_load, device)

# %%
model = EmnistModel()
to_device(model, device)
# Out:
# EmnistModel(
#   (network): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Flatten(start_dim=1, end_dim=-1)
#     (11): Linear(in_features=12544, out_features=1024, bias=True)
#     (12): ReLU()
#     (13): Linear(in_features=1024, out_features=256, bias=True)
#     (14): ReLU()
#     (15): Linear(in_features=256, out_features=27, bias=True)
#   )
# )

# %% [markdown]
# ##### Here you have to implement the train function of your model.
#
# ##### A test function is provided for the evaluation of the model.

# %%
def train(epoch, net, optimizer, criterion, trainloader):
    net.train()
    for batch_idx, (images, labels) in enumerate(trainloader):
        ## Initialize the model
        ##  classify the images using the model
        ## compute the loss between the real labels and predicted labels
        ## backpropagate the loss
        ## update the optimizer
        images, labels = images.to(device) , labels.to(device)
        net.zero_grad()
        outputs = net(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        ## display the loss & epoch, every 10 batchs for instance.
        #print("Loss:"+ str(loss.item()) + ", Epoch:" + str(epoch) + ", Batch number "+ str(batch_idx))
def test(model, criterion, testloader):
    model.eval()
    loss, total, correct = 0.0, 0.0, 0.0

    for batch_idx, (images, labels) in enumerate(testloader):
        #images, labels = images.to(device), labels.to(device)

        # Inference
        outputs = model(images)
        batch_loss = criterion(outputs, labels)
        loss += batch_loss.item()

        # Prediction
        _, pred_labels = torch.max(outputs, 1)
        pred_labels = pred_labels.view(-1)
        correct += torch.sum(torch.eq(pred_labels, labels)).item()
        total += len(labels)

    accuracy = correct / total
    return accuracy*100, loss

# %% [markdown]
# See Documentation : https://pytorch.org/docs/stable/generated/torch.optim.SGD.html and https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html

# %%
from time import time
from torch.utils.data import DataLoader
import torch.optim as optim

def main():
    
    ## You can play with these parameters & observe how they effect the training process.
    learning_rate = 0.001
    batch_size = 64 
    epochs = 5 
    
    
    ## instantiate your model
    net = EmnistModel()
    net.to(device)
    ## create two dataloaders (train & test) to load data into batches

    trainloader = DataLoader(train_dataset, batch_size, shuffle = True)

    testloader = DataLoader(test_dataset, batch_size, shuffle = True)

    train_loader = DeviceDataLoader(trainloader, device)
    test_loader = DeviceDataLoader(testloader, device)
    ## instantiate an optimizer for you model, as well as a criterion/loss function - SGD
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(net.parameters())
    
    # Evaluating the model before any training steps is a good practice
    accuracy, loss = test(net, criterion, test_loader)
    print('Before training :',f'Accuracy: {accuracy}', f'Loss: {loss}' )
    
    time0 = time() 
    for epoch in range(epochs):
        train(epoch, net, optimizer, criterion, train_loader)
        accuracy, loss = test(net, criterion, test_loader)
        print(f'Epoch :{epoch}',f'Accuracy: {accuracy}', f'Loss: {loss}' )
    print(f'Training Time (minutes) :{(time()-time0) / 60}')

# %%
main()
# Out:
# Before training : Accuracy: 3.817307692307692 Loss: 1070.5490567684174
# Loss:3.299219846725464, Epoch:0, Batch number 0
# Loss:3.304894208908081, Epoch:0, Batch number 1
# Loss:3.2875916957855225, Epoch:0, Batch number 2
# Loss:3.2828304767608643, Epoch:0, Batch number 3
# Loss:3.2469780445098877, Epoch:0, Batch number 4
# Loss:3.1939358711242676, Epoch:0, Batch number 5
# Loss:3.225059986114502, Epoch:0, Batch number 6
# Loss:3.1818392276763916, Epoch:0, Batch number 7
# Loss:3.120201349258423, Epoch:0, Batch number 8
# Loss:3.022217273712158, Epoch:0, Batch number 9
# Loss:2.9164206981658936, Epoch:0, Batch number 10
# Loss:2.719472646713257, Epoch:0, Batch number 11
# Loss:2.5306291580200195, Epoch:0, Batch number 12
# Loss:2.3410611152648926, Epoch:0, Batch number 13
# Loss:2.3856587409973145, Epoch:0, Batch number 14
# Loss:2.1283600330352783, Epoch:0, Batch number 15
# Loss:2.1580984592437744, Epoch:0, Batch number 16
# Loss:2.2128746509552, Epoch:0, Batch number 17
# Loss:1.8170918226242065, Epoch:0, Batch number 18
# Loss:2.0208370685577393, Epoch:0, Batch number 19
# Loss:1.825622797012329, Epoch:0, Batch number 20
# Loss:1.5558089017868042, Epoch:0, Batch number 21
# Loss:1.4106450080871582, Epoch:0, Batch number 22
# Loss:2.068479299545288, Epoch:0, Batch number 23
# Loss:1.4244840145111084, Epoch:0, Batch number 24
# Loss:1.3184419870376587, Epoch:0, Batch number 25
# Loss:1.5861340761184692, Epoch:0, Batch number 26
# Loss:1.5596225261688232, Epoch:0, Batch number 27
# Loss:1.2384045124053955, Epoch:0, Batch number 28
# Loss:1.3064744472503662, Epoch:0, Batch number 29
# Loss:1.1821078062057495, Epoch:0, Batch number 30
# Loss:1.3125537633895874, Epoch:0, Batch number 31
# Loss:1.2802891731262207, Epoch:0, Batch number 32
# Loss:1.466211199760437, Epoch:0, Batch number 33
# Loss:0.965175449848175, Epoch:0, Batch number 34
# Loss:1.4228986501693726, Epoch:0, Batch number 35
# Loss:0.8967551589012146, Epoch:0, Batch number 36
# Loss:1.1137118339538574, Epoch:0, Batch number 37
# Loss:1.0995041131973267, Epoch:0, Batch number 38
# Loss:1.079241394996643, Epoch:0, Batch number 39
# Loss:1.1521118879318237, Epoch:0, Batch number 40
# Loss:1.2203121185302734, Epoch:0, Batch number 41
# Loss:0.8757171034812927, Epoch:0, Batch number 42
# Loss:0.8784452080726624, Epoch:0, Batch number 43
# Loss:1.1715023517608643, Epoch:0, Batch number 44
# Loss:0.9210880994796753, Epoch:0, Batch number 45
# Loss:0.8713626265525818, Epoch:0, Batch number 46
# Loss:0.9003227353096008, Epoch:0, Batch number 47
# Loss:0.7734106183052063, Epoch:0, Batch number 48
# Loss:1.1445907354354858, Epoch:0, Batch number 49
# Loss:1.1298681497573853, Epoch:0, Batch number 50
# Loss:1.2117735147476196, Epoch:0, Batch number 51
# Loss:0.8950393199920654, Epoch:0, Batch number 52
# Loss:0.9612940549850464, Epoch:0, Batch number 53
# Loss:0.9126027822494507, Epoch:0, Batch number 54
# Loss:0.6651499271392822, Epoch:0, Batch number 55
# Loss:0.7284743189811707, Epoch:0, Batch number 56
# Loss:0.715450644493103, Epoch:0, Batch number 57
# Loss:0.8536141514778137, Epoch:0, Batch number 58
# Loss:0.6834693551063538, Epoch:0, Batch number 59
# Loss:0.9121110439300537, Epoch:0, Batch number 60
# Loss:0.568660318851471, Epoch:0, Batch number 61
# Loss:0.7368758916854858, Epoch:0, Batch number 62
# Loss:0.7890728712081909, Epoch:0, Batch number 63
# Loss:0.7943060994148254, Epoch:0, Batch number 64
# Loss:0.8780482411384583, Epoch:0, Batch number 65
# Loss:0.9574266076087952, Epoch:0, Batch number 66
# Loss:0.7671710848808289, Epoch:0, Batch number 67
# Loss:0.8363173007965088, Epoch:0, Batch number 68
# Loss:0.7838083505630493, Epoch:0, Batch number 69
# Loss:0.7805464267730713, Epoch:0, Batch number 70
# Loss:1.0549107789993286, Epoch:0, Batch number 71
# Loss:0.6878050565719604, Epoch:0, Batch number 72
# Loss:0.8111175298690796, Epoch:0, Batch number 73
# Loss:0.6636642217636108, Epoch:0, Batch number 74
# Loss:0.7567875981330872, Epoch:0, Batch number 75
# Loss:0.4448532462120056, Epoch:0, Batch number 76
# Loss:0.8667155504226685, Epoch:0, Batch number 77
# Loss:0.6504895091056824, Epoch:0, Batch number 78
# Loss:0.73993319272995, Epoch:0, Batch number 79
# Loss:0.5439403057098389, Epoch:0, Batch number 80
# Loss:0.4177878797054291, Epoch:0, Batch number 81
# Loss:0.6479918360710144, Epoch:0, Batch number 82
# Loss:0.37962183356285095, Epoch:0, Batch number 83
# Loss:0.8764286041259766, Epoch:0, Batch number 84
# Loss:0.4646311104297638, Epoch:0, Batch number 85
# Loss:0.7469517588615417, Epoch:0, Batch number 86
# Loss:0.5782596468925476, Epoch:0, Batch number 87
# Loss:0.48252615332603455, Epoch:0, Batch number 88
# Loss:0.7155940532684326, Epoch:0, Batch number 89
# Loss:0.4261745512485504, Epoch:0, Batch number 90
# Loss:0.6805997490882874, Epoch:0, Batch number 91
# Loss:0.4629010260105133, Epoch:0, Batch number 92
# Loss:0.8636666536331177, Epoch:0, Batch number 93
# Loss:0.5807382464408875, Epoch:0, Batch number 94
# Loss:0.5919193029403687, Epoch:0, Batch number 95
# Loss:0.753966748714447, Epoch:0, Batch number 96
# Loss:0.525103747844696, Epoch:0, Batch number 97
# Loss:0.715033769607544, Epoch:0, Batch number 98
# Loss:0.9716203808784485, Epoch:0, Batch number 99
# Loss:0.6787428259849548, Epoch:0, Batch number 100
# Loss:0.6264999508857727, Epoch:0, Batch number 101
# Loss:0.4077012538909912, Epoch:0, Batch number 102
# Loss:0.5629381537437439, Epoch:0, Batch number 103
# Loss:0.48798251152038574, Epoch:0, Batch number 104
# Loss:0.6831084489822388, Epoch:0, Batch number 105
# Loss:0.41939738392829895, Epoch:0, Batch number 106
# Loss:0.7292693853378296, Epoch:0, Batch number 107
# Loss:0.5374701619148254, Epoch:0, Batch number 108
# Loss:0.7201818227767944, Epoch:0, Batch number 109
# Loss:0.5407549142837524, Epoch:0, Batch number 110
# Loss:0.43465834856033325, Epoch:0, Batch number 111
# Loss:0.5149412751197815, Epoch:0, Batch number 112
# Loss:0.5742214918136597, Epoch:0, Batch number 113
# Loss:0.7181274890899658, Epoch:0, Batch number 114
# Loss:0.6739099621772766, Epoch:0, Batch number 115
# Loss:0.5347707271575928, Epoch:0, Batch number 116
# Loss:0.5754356980323792, Epoch:0, Batch number 117
# Loss:0.38941690325737, Epoch:0, Batch number 118
# Loss:0.6439028978347778, Epoch:0, Batch number 119
# Loss:0.23710861802101135, Epoch:0, Batch number 120
# Loss:0.49761030077934265, Epoch:0, Batch number 121
# Loss:0.5091714262962341, Epoch:0, Batch number 122
# Loss:0.5094603300094604, Epoch:0, Batch number 123
# Loss:0.8138350248336792, Epoch:0, Batch number 124
# Loss:0.4655234217643738, Epoch:0, Batch number 125
# Loss:0.6579697132110596, Epoch:0, Batch number 126
# Loss:0.5324385762214661, Epoch:0, Batch number 127
# Loss:0.7148942351341248, Epoch:0, Batch number 128
# Loss:0.49084773659706116, Epoch:0, Batch number 129
# Loss:0.5050539970397949, Epoch:0, Batch number 130
# Loss:0.6945611238479614, Epoch:0, Batch number 131
# Loss:0.624192476272583, Epoch:0, Batch number 132
# Loss:0.6087232828140259, Epoch:0, Batch number 133
# Loss:0.41286391019821167, Epoch:0, Batch number 134
# Loss:0.5755235552787781, Epoch:0, Batch number 135
# Loss:0.7715065479278564, Epoch:0, Batch number 136
# Loss:0.5894380211830139, Epoch:0, Batch number 137
# Loss:0.2749517261981964, Epoch:0, Batch number 138
# Loss:0.6100391149520874, Epoch:0, Batch number 139
# Loss:0.5498575568199158, Epoch:0, Batch number 140
# Loss:0.6550530195236206, Epoch:0, Batch number 141
# Loss:0.47965115308761597, Epoch:0, Batch number 142
# Loss:0.3657858073711395, Epoch:0, Batch number 143
# Loss:0.3462876081466675, Epoch:0, Batch number 144
# Loss:0.6103165745735168, Epoch:0, Batch number 145
# Loss:0.5140946507453918, Epoch:0, Batch number 146
# Loss:0.5169181227684021, Epoch:0, Batch number 147
# Loss:0.48563387989997864, Epoch:0, Batch number 148
# Loss:0.4044370949268341, Epoch:0, Batch number 149
# Loss:0.7278670072555542, Epoch:0, Batch number 150
# Loss:1.04460871219635, Epoch:0, Batch number 151
# Loss:0.34638336300849915, Epoch:0, Batch number 152
# Loss:0.45965200662612915, Epoch:0, Batch number 153
# Loss:0.43707191944122314, Epoch:0, Batch number 154
# Loss:0.6339380145072937, Epoch:0, Batch number 155
# Loss:0.545745313167572, Epoch:0, Batch number 156
# Loss:0.8206807374954224, Epoch:0, Batch number 157
# Loss:0.38679203391075134, Epoch:0, Batch number 158
# Loss:0.44336745142936707, Epoch:0, Batch number 159
# Loss:0.6225282549858093, Epoch:0, Batch number 160
# Loss:0.7101705074310303, Epoch:0, Batch number 161
# Loss:0.340191125869751, Epoch:0, Batch number 162
# Loss:0.44327157735824585, Epoch:0, Batch number 163
# Loss:0.43684276938438416, Epoch:0, Batch number 164
# Loss:0.2671523094177246, Epoch:0, Batch number 165
# Loss:0.48526474833488464, Epoch:0, Batch number 166
# Loss:0.4808558523654938, Epoch:0, Batch number 167
# Loss:0.24906687438488007, Epoch:0, Batch number 168
# Loss:0.4934942126274109, Epoch:0, Batch number 169
# Loss:0.47730758786201477, Epoch:0, Batch number 170
# Loss:0.5565430521965027, Epoch:0, Batch number 171
# Loss:0.2582854628562927, Epoch:0, Batch number 172
# Loss:0.3830154240131378, Epoch:0, Batch number 173
# Loss:0.4328627586364746, Epoch:0, Batch number 174
# Loss:0.6053237318992615, Epoch:0, Batch number 175
# Loss:0.5445001125335693, Epoch:0, Batch number 176
# Loss:0.3620587885379791, Epoch:0, Batch number 177
# Loss:0.27667492628097534, Epoch:0, Batch number 178
# Loss:0.6443281173706055, Epoch:0, Batch number 179
# Loss:0.5578141808509827, Epoch:0, Batch number 180
# Loss:0.34540924429893494, Epoch:0, Batch number 181
# Loss:0.41513732075691223, Epoch:0, Batch number 182
# Loss:0.5526058077812195, Epoch:0, Batch number 183
# Loss:0.4178287982940674, Epoch:0, Batch number 184
# Loss:0.28951147198677063, Epoch:0, Batch number 185
# Loss:0.44015488028526306, Epoch:0, Batch number 186
# Loss:0.7440852522850037, Epoch:0, Batch number 187
# Loss:0.386236310005188, Epoch:0, Batch number 188
# Loss:0.7367780208587646, Epoch:0, Batch number 189
# Loss:0.3661894202232361, Epoch:0, Batch number 190
# Loss:0.636204183101654, Epoch:0, Batch number 191
# Loss:0.24069295823574066, Epoch:0, Batch number 192
# Loss:0.3741503655910492, Epoch:0, Batch number 193
# Loss:0.5364503264427185, Epoch:0, Batch number 194
# Loss:0.4334748685359955, Epoch:0, Batch number 195
# Loss:0.30743950605392456, Epoch:0, Batch number 196
# Loss:0.353514164686203, Epoch:0, Batch number 197
# Loss:0.6181970834732056, Epoch:0, Batch number 198
# Loss:0.2692582905292511, Epoch:0, Batch number 199
# Loss:0.6159415245056152, Epoch:0, Batch number 200
# Loss:0.3238394260406494, Epoch:0, Batch number 201
# Loss:0.3664357662200928, Epoch:0, Batch number 202
# Loss:0.47031888365745544, Epoch:0, Batch number 203
# Loss:0.32093581557273865, Epoch:0, Batch number 204
# Loss:0.5539328455924988, Epoch:0, Batch number 205
# Loss:0.4096010625362396, Epoch:0, Batch number 206
# Loss:0.6893030405044556, Epoch:0, Batch number 207
# Loss:0.19744817912578583, Epoch:0, Batch number 208
# Loss:0.3174826204776764, Epoch:0, Batch number 209
# Loss:0.17633698880672455, Epoch:0, Batch number 210
# Loss:0.7488480806350708, Epoch:0, Batch number 211
# Loss:0.507255494594574, Epoch:0, Batch number 212
# Loss:0.3031352460384369, Epoch:0, Batch number 213
# Loss:0.3110448122024536, Epoch:0, Batch number 214
# Loss:0.41865238547325134, Epoch:0, Batch number 215
# Loss:0.3755449652671814, Epoch:0, Batch number 216
# Loss:0.29008638858795166, Epoch:0, Batch number 217
# Loss:0.3637024462223053, Epoch:0, Batch number 218
# Loss:0.3082234859466553, Epoch:0, Batch number 219
# Loss:0.5277816653251648, Epoch:0, Batch number 220
# Loss:0.3853131830692291, Epoch:0, Batch number 221
# Loss:0.7650502920150757, Epoch:0, Batch number 222
# Loss:0.27557092905044556, Epoch:0, Batch number 223
# Loss:0.5182921290397644, Epoch:0, Batch number 224
# Loss:0.2949947118759155, Epoch:0, Batch number 225
# Loss:0.6043000221252441, Epoch:0, Batch number 226
# Loss:0.34729695320129395, Epoch:0, Batch number 227
# Loss:0.3116004467010498, Epoch:0, Batch number 228
# Loss:0.48217952251434326, Epoch:0, Batch number 229
# Loss:0.3781326413154602, Epoch:0, Batch number 230
# Loss:0.4516368806362152, Epoch:0, Batch number 231
# Loss:0.4374290704727173, Epoch:0, Batch number 232
# Loss:0.435381144285202, Epoch:0, Batch number 233
# Loss:0.4903249740600586, Epoch:0, Batch number 234
# Loss:0.2558515667915344, Epoch:0, Batch number 235
# Loss:0.4101885259151459, Epoch:0, Batch number 236
# Loss:0.2585464417934418, Epoch:0, Batch number 237
# Loss:0.47817906737327576, Epoch:0, Batch number 238
# Loss:0.25368261337280273, Epoch:0, Batch number 239
# Loss:0.26933518052101135, Epoch:0, Batch number 240
# Loss:0.4038642644882202, Epoch:0, Batch number 241
# Loss:0.6727575063705444, Epoch:0, Batch number 242
# Loss:0.43491604924201965, Epoch:0, Batch number 243
# Loss:0.5816704034805298, Epoch:0, Batch number 244
# Loss:0.2942422926425934, Epoch:0, Batch number 245
# Loss:0.2109869420528412, Epoch:0, Batch number 246
# Loss:0.4284510016441345, Epoch:0, Batch number 247
# Loss:0.5063323378562927, Epoch:0, Batch number 248
# Loss:0.21942488849163055, Epoch:0, Batch number 249
# Loss:0.49906206130981445, Epoch:0, Batch number 250
# Loss:0.4792349636554718, Epoch:0, Batch number 251
# Loss:0.4175986051559448, Epoch:0, Batch number 252
# Loss:0.40205296874046326, Epoch:0, Batch number 253
# Loss:0.4507765471935272, Epoch:0, Batch number 254
# Loss:0.26057571172714233, Epoch:0, Batch number 255
# Loss:0.37955161929130554, Epoch:0, Batch number 256
# Loss:0.30668801069259644, Epoch:0, Batch number 257
# Loss:0.34019821882247925, Epoch:0, Batch number 258
# Loss:0.3931415379047394, Epoch:0, Batch number 259
# Loss:0.3030204474925995, Epoch:0, Batch number 260
# Loss:0.16106988489627838, Epoch:0, Batch number 261
# Loss:0.21572905778884888, Epoch:0, Batch number 262
# Loss:0.3429388701915741, Epoch:0, Batch number 263
# Loss:0.4156115651130676, Epoch:0, Batch number 264
# Loss:0.30491572618484497, Epoch:0, Batch number 265
# Loss:0.33812403678894043, Epoch:0, Batch number 266
# Loss:0.23590952157974243, Epoch:0, Batch number 267
# Loss:0.435991108417511, Epoch:0, Batch number 268
# Loss:0.4049927592277527, Epoch:0, Batch number 269
# Loss:0.3479674160480499, Epoch:0, Batch number 270
# Loss:0.3045431673526764, Epoch:0, Batch number 271
# Loss:0.3126727342605591, Epoch:0, Batch number 272
# Loss:0.38068002462387085, Epoch:0, Batch number 273
# Loss:0.2962387800216675, Epoch:0, Batch number 274
# Loss:0.3443435728549957, Epoch:0, Batch number 275
# Loss:0.2061721533536911, Epoch:0, Batch number 276
# Loss:0.3535328805446625, Epoch:0, Batch number 277
# Loss:0.40818849205970764, Epoch:0, Batch number 278
# Loss:0.5808733701705933, Epoch:0, Batch number 279
# Loss:0.4758848249912262, Epoch:0, Batch number 280
# Loss:0.5412185788154602, Epoch:0, Batch number 281
# Loss:0.40629565715789795, Epoch:0, Batch number 282
# Loss:0.32803529500961304, Epoch:0, Batch number 283
# Loss:0.2911476790904999, Epoch:0, Batch number 284
# Loss:0.5105253458023071, Epoch:0, Batch number 285
# Loss:0.31045278906822205, Epoch:0, Batch number 286
# Loss:0.27523189783096313, Epoch:0, Batch number 287
# Loss:0.30434951186180115, Epoch:0, Batch number 288
# Loss:0.5349421501159668, Epoch:0, Batch number 289
# Loss:0.4194081723690033, Epoch:0, Batch number 290
# Loss:0.27142319083213806, Epoch:0, Batch number 291
# Loss:0.34019041061401367, Epoch:0, Batch number 292
# Loss:0.31536203622817993, Epoch:0, Batch number 293
# Loss:0.6042890548706055, Epoch:0, Batch number 294
# Loss:0.3305826485157013, Epoch:0, Batch number 295
# Loss:0.26912838220596313, Epoch:0, Batch number 296
# Loss:0.3683466613292694, Epoch:0, Batch number 297
# Loss:0.44654759764671326, Epoch:0, Batch number 298
# Loss:0.4290176331996918, Epoch:0, Batch number 299
# Loss:0.16182801127433777, Epoch:0, Batch number 300
# Loss:0.3555196523666382, Epoch:0, Batch number 301
# Loss:0.15079553425312042, Epoch:0, Batch number 302
# Loss:0.18468789756298065, Epoch:0, Batch number 303
# Loss:0.3442227244377136, Epoch:0, Batch number 304
# Loss:0.30677568912506104, Epoch:0, Batch number 305
# Loss:0.30493882298469543, Epoch:0, Batch number 306
# Loss:0.24693693220615387, Epoch:0, Batch number 307
# Loss:0.3506056070327759, Epoch:0, Batch number 308
# Loss:0.3466915190219879, Epoch:0, Batch number 309
# Loss:0.28425711393356323, Epoch:0, Batch number 310
# Loss:0.22522403299808502, Epoch:0, Batch number 311
# Loss:0.2475551813840866, Epoch:0, Batch number 312
# Loss:0.1906583309173584, Epoch:0, Batch number 313
# Loss:0.2782232463359833, Epoch:0, Batch number 314
# Loss:0.39590293169021606, Epoch:0, Batch number 315
# Loss:0.26508277654647827, Epoch:0, Batch number 316
# Loss:0.38775262236595154, Epoch:0, Batch number 317
# Loss:0.392985075712204, Epoch:0, Batch number 318
# Loss:0.4075610637664795, Epoch:0, Batch number 319
# Loss:0.22544395923614502, Epoch:0, Batch number 320
# Loss:0.38261350989341736, Epoch:0, Batch number 321
# Loss:0.4725121855735779, Epoch:0, Batch number 322
# Loss:0.3210994005203247, Epoch:0, Batch number 323
# Loss:0.6101670861244202, Epoch:0, Batch number 324
# Loss:0.39614570140838623, Epoch:0, Batch number 325
# Loss:0.3670128881931305, Epoch:0, Batch number 326
# Loss:0.3278011083602905, Epoch:0, Batch number 327
# Loss:0.2662086486816406, Epoch:0, Batch number 328
# Loss:0.33119311928749084, Epoch:0, Batch number 329
# Loss:0.45648953318595886, Epoch:0, Batch number 330
# Loss:0.2795654237270355, Epoch:0, Batch number 331
# Loss:0.32654792070388794, Epoch:0, Batch number 332
# Loss:0.2828214168548584, Epoch:0, Batch number 333
# Loss:0.41653522849082947, Epoch:0, Batch number 334
# Loss:0.24282795190811157, Epoch:0, Batch number 335
# Loss:0.17023640871047974, Epoch:0, Batch number 336
# Loss:0.34573471546173096, Epoch:0, Batch number 337
# Loss:0.27794960141181946, Epoch:0, Batch number 338
# Loss:0.5453259944915771, Epoch:0, Batch number 339
# Loss:0.2639252543449402, Epoch:0, Batch number 340
# Loss:0.30750203132629395, Epoch:0, Batch number 341
# Loss:0.362559050321579, Epoch:0, Batch number 342
# Loss:0.3463513255119324, Epoch:0, Batch number 343
# Loss:0.3140464723110199, Epoch:0, Batch number 344
# Loss:0.516918957233429, Epoch:0, Batch number 345
# Loss:0.36654046177864075, Epoch:0, Batch number 346
# Loss:0.32629621028900146, Epoch:0, Batch number 347
# Loss:0.6743291020393372, Epoch:0, Batch number 348
# Loss:0.40056779980659485, Epoch:0, Batch number 349
# Loss:0.33847108483314514, Epoch:0, Batch number 350
# Loss:0.2867106795310974, Epoch:0, Batch number 351
# Loss:0.2743925154209137, Epoch:0, Batch number 352
# Loss:0.34709370136260986, Epoch:0, Batch number 353
# Loss:0.3038967251777649, Epoch:0, Batch number 354
# Loss:0.2250218689441681, Epoch:0, Batch number 355
# Loss:0.4335920810699463, Epoch:0, Batch number 356
# Loss:0.3559631109237671, Epoch:0, Batch number 357
# Loss:0.3991222679615021, Epoch:0, Batch number 358
# Loss:0.26752644777297974, Epoch:0, Batch number 359
# Loss:0.2629704177379608, Epoch:0, Batch number 360
# Loss:0.2876783013343811, Epoch:0, Batch number 361
# Loss:0.5438001155853271, Epoch:0, Batch number 362
# Loss:0.3749435544013977, Epoch:0, Batch number 363
# Loss:0.4356444478034973, Epoch:0, Batch number 364
# Loss:0.17518740892410278, Epoch:0, Batch number 365
# Loss:0.2619718015193939, Epoch:0, Batch number 366
# Loss:0.41632893681526184, Epoch:0, Batch number 367
# Loss:0.4110123813152313, Epoch:0, Batch number 368
# Loss:0.3824605941772461, Epoch:0, Batch number 369
# Loss:0.2758854031562805, Epoch:0, Batch number 370
# Loss:0.28685951232910156, Epoch:0, Batch number 371
# Loss:0.40323638916015625, Epoch:0, Batch number 372
# Loss:0.39974290132522583, Epoch:0, Batch number 373
# Loss:0.5631007552146912, Epoch:0, Batch number 374
# Loss:0.16899484395980835, Epoch:0, Batch number 375
# Loss:0.2502974569797516, Epoch:0, Batch number 376
# Loss:0.2759287655353546, Epoch:0, Batch number 377
# Loss:0.20422567427158356, Epoch:0, Batch number 378
# Loss:0.21187815070152283, Epoch:0, Batch number 379
# Loss:0.21485579013824463, Epoch:0, Batch number 380
# Loss:0.11573890596628189, Epoch:0, Batch number 381
# Loss:0.2878324091434479, Epoch:0, Batch number 382
# Loss:0.2430655062198639, Epoch:0, Batch number 383
# Loss:0.44715332984924316, Epoch:0, Batch number 384
# Loss:0.4377198815345764, Epoch:0, Batch number 385
# Loss:0.31280383467674255, Epoch:0, Batch number 386
# Loss:0.2666777968406677, Epoch:0, Batch number 387
# Loss:0.4693593382835388, Epoch:0, Batch number 388
# Loss:0.3591230511665344, Epoch:0, Batch number 389
# Loss:0.3304001986980438, Epoch:0, Batch number 390
# Loss:0.19866469502449036, Epoch:0, Batch number 391
# Loss:0.1811337172985077, Epoch:0, Batch number 392
# Loss:0.4190213978290558, Epoch:0, Batch number 393
# Loss:0.21057559549808502, Epoch:0, Batch number 394
# Loss:0.21849708259105682, Epoch:0, Batch number 395
# Loss:0.19232642650604248, Epoch:0, Batch number 396
# Loss:0.25783196091651917, Epoch:0, Batch number 397
# Loss:0.17049676179885864, Epoch:0, Batch number 398
# Loss:0.26052752137184143, Epoch:0, Batch number 399
# Loss:0.48996981978416443, Epoch:0, Batch number 400
# Loss:0.23046278953552246, Epoch:0, Batch number 401
# Loss:0.2645525336265564, Epoch:0, Batch number 402
# Loss:0.15587764978408813, Epoch:0, Batch number 403
# Loss:0.3730970621109009, Epoch:0, Batch number 404
# Loss:0.27612584829330444, Epoch:0, Batch number 405
# Loss:0.12374968826770782, Epoch:0, Batch number 406
# Loss:0.4375598430633545, Epoch:0, Batch number 407
# Loss:0.29458147287368774, Epoch:0, Batch number 408
# Loss:0.33339932560920715, Epoch:0, Batch number 409
# Loss:0.7509692907333374, Epoch:0, Batch number 410
# Loss:0.2682461142539978, Epoch:0, Batch number 411
# Loss:0.33232447504997253, Epoch:0, Batch number 412
# Loss:0.2439592480659485, Epoch:0, Batch number 413
# Loss:0.26188865303993225, Epoch:0, Batch number 414
# Loss:0.5388442873954773, Epoch:0, Batch number 415
# Loss:0.4073803424835205, Epoch:0, Batch number 416
# Loss:0.40853726863861084, Epoch:0, Batch number 417
# Loss:0.3034103810787201, Epoch:0, Batch number 418
# Loss:0.2708362638950348, Epoch:0, Batch number 419
# Loss:0.375000923871994, Epoch:0, Batch number 420
# Loss:0.2862209677696228, Epoch:0, Batch number 421
# Loss:0.30009573698043823, Epoch:0, Batch number 422
# Loss:0.4740476906299591, Epoch:0, Batch number 423
# Loss:0.40946900844573975, Epoch:0, Batch number 424
# Loss:0.31634700298309326, Epoch:0, Batch number 425
# Loss:0.11310359090566635, Epoch:0, Batch number 426
# Loss:0.31413620710372925, Epoch:0, Batch number 427
# Loss:0.2327398955821991, Epoch:0, Batch number 428
# Loss:0.5516148209571838, Epoch:0, Batch number 429
# Loss:0.27885252237319946, Epoch:0, Batch number 430
# Loss:0.08520416915416718, Epoch:0, Batch number 431
# Loss:0.3818160593509674, Epoch:0, Batch number 432
# Loss:0.23463261127471924, Epoch:0, Batch number 433
# Loss:0.35076212882995605, Epoch:0, Batch number 434
# Loss:0.2959246337413788, Epoch:0, Batch number 435
# Loss:0.12670928239822388, Epoch:0, Batch number 436
# Loss:0.20685112476348877, Epoch:0, Batch number 437
# Loss:0.28245529532432556, Epoch:0, Batch number 438
# Loss:0.25866907835006714, Epoch:0, Batch number 439
# Loss:0.27848851680755615, Epoch:0, Batch number 440
# Loss:0.15682846307754517, Epoch:0, Batch number 441
# Loss:0.4154963791370392, Epoch:0, Batch number 442
# Loss:0.2123531997203827, Epoch:0, Batch number 443
# Loss:0.27032148838043213, Epoch:0, Batch number 444
# Loss:0.09501101076602936, Epoch:0, Batch number 445
# Loss:0.35920777916908264, Epoch:0, Batch number 446
# Loss:0.25325384736061096, Epoch:0, Batch number 447
# Loss:0.23888711631298065, Epoch:0, Batch number 448
# Loss:0.4572746753692627, Epoch:0, Batch number 449
# Loss:0.08911348134279251, Epoch:0, Batch number 450
# Loss:0.18324869871139526, Epoch:0, Batch number 451
# Loss:0.1542038917541504, Epoch:0, Batch number 452
# Loss:0.3685418963432312, Epoch:0, Batch number 453
# Loss:0.2229781150817871, Epoch:0, Batch number 454
# Loss:0.38120266795158386, Epoch:0, Batch number 455
# Loss:0.3101367950439453, Epoch:0, Batch number 456
# Loss:0.1283901184797287, Epoch:0, Batch number 457
# Loss:0.3657810091972351, Epoch:0, Batch number 458
# Loss:0.2708428204059601, Epoch:0, Batch number 459
# Loss:0.20561550557613373, Epoch:0, Batch number 460
# Loss:0.4408291280269623, Epoch:0, Batch number 461
# Loss:0.19444409012794495, Epoch:0, Batch number 462
# Loss:0.18069696426391602, Epoch:0, Batch number 463
# Loss:0.20709963142871857, Epoch:0, Batch number 464
# Loss:0.15137621760368347, Epoch:0, Batch number 465
# Loss:0.3028044104576111, Epoch:0, Batch number 466
# Loss:0.12410078197717667, Epoch:0, Batch number 467
# Loss:0.12602105736732483, Epoch:0, Batch number 468
# Loss:0.31283795833587646, Epoch:0, Batch number 469
# Loss:0.1891903579235077, Epoch:0, Batch number 470
# Loss:0.3028102219104767, Epoch:0, Batch number 471
# Loss:0.2744981050491333, Epoch:0, Batch number 472
# Loss:0.37488245964050293, Epoch:0, Batch number 473
# Loss:0.37047871947288513, Epoch:0, Batch number 474
# Loss:0.4836023449897766, Epoch:0, Batch number 475
# Loss:0.27172818779945374, Epoch:0, Batch number 476
# Loss:0.22244182229042053, Epoch:0, Batch number 477
# Loss:0.3041391968727112, Epoch:0, Batch number 478
# Loss:0.3357428312301636, Epoch:0, Batch number 479
# Loss:0.16876952350139618, Epoch:0, Batch number 480
# Loss:0.5262929201126099, Epoch:0, Batch number 481
# Loss:0.3967660963535309, Epoch:0, Batch number 482
# Loss:0.32275092601776123, Epoch:0, Batch number 483
# Loss:0.41837847232818604, Epoch:0, Batch number 484
# Loss:0.36933037638664246, Epoch:0, Batch number 485
# Loss:0.6941155791282654, Epoch:0, Batch number 486
# Loss:0.3685617446899414, Epoch:0, Batch number 487
# Loss:0.20807425677776337, Epoch:0, Batch number 488
# Loss:0.28998497128486633, Epoch:0, Batch number 489
# Loss:0.4702332317829132, Epoch:0, Batch number 490
# Loss:0.4045183062553406, Epoch:0, Batch number 491
# Loss:0.17500805854797363, Epoch:0, Batch number 492
# Loss:0.39493945240974426, Epoch:0, Batch number 493
# Loss:0.39778435230255127, Epoch:0, Batch number 494
# Loss:0.23809106647968292, Epoch:0, Batch number 495
# Loss:0.37923502922058105, Epoch:0, Batch number 496
# Loss:0.26911860704421997, Epoch:0, Batch number 497
# Loss:0.17231503129005432, Epoch:0, Batch number 498
# Loss:0.4938969910144806, Epoch:0, Batch number 499
# Loss:0.19798611104488373, Epoch:0, Batch number 500
# Loss:0.1475878804922104, Epoch:0, Batch number 501
# Loss:0.23461449146270752, Epoch:0, Batch number 502
# Loss:0.4025788903236389, Epoch:0, Batch number 503
# Loss:0.3546704649925232, Epoch:0, Batch number 504
# Loss:0.2235308140516281, Epoch:0, Batch number 505
# Loss:0.34449702501296997, Epoch:0, Batch number 506
# Loss:0.3651106357574463, Epoch:0, Batch number 507
# Loss:0.22573618590831757, Epoch:0, Batch number 508
# Loss:0.179280623793602, Epoch:0, Batch number 509
# Loss:0.4307502806186676, Epoch:0, Batch number 510
# Loss:0.2349947988986969, Epoch:0, Batch number 511
# Loss:0.2310624122619629, Epoch:0, Batch number 512
# Loss:0.3176492750644684, Epoch:0, Batch number 513
# Loss:0.3619586229324341, Epoch:0, Batch number 514
# Loss:0.24863173067569733, Epoch:0, Batch number 515
# Loss:0.35949093103408813, Epoch:0, Batch number 516
# Loss:0.15312322974205017, Epoch:0, Batch number 517
# Loss:0.3120802640914917, Epoch:0, Batch number 518
# Loss:0.41535547375679016, Epoch:0, Batch number 519
# Loss:0.17599821090698242, Epoch:0, Batch number 520
# Loss:0.208897203207016, Epoch:0, Batch number 521
# Loss:0.2375054955482483, Epoch:0, Batch number 522
# Loss:0.27455562353134155, Epoch:0, Batch number 523
# Loss:0.33808013796806335, Epoch:0, Batch number 524
# Loss:0.3223157227039337, Epoch:0, Batch number 525
# Loss:0.34634119272232056, Epoch:0, Batch number 526
# Loss:0.20063728094100952, Epoch:0, Batch number 527
# Loss:0.2375105917453766, Epoch:0, Batch number 528
# Loss:0.23583823442459106, Epoch:0, Batch number 529
# Loss:0.31230196356773376, Epoch:0, Batch number 530
# Loss:0.5480990409851074, Epoch:0, Batch number 531
# Loss:0.42953914403915405, Epoch:0, Batch number 532
# Loss:0.37364161014556885, Epoch:0, Batch number 533
# Loss:0.43133923411369324, Epoch:0, Batch number 534
# Loss:0.3493557274341583, Epoch:0, Batch number 535
# Loss:0.4315062165260315, Epoch:0, Batch number 536
# Loss:0.2427559494972229, Epoch:0, Batch number 537
# Loss:0.1402633935213089, Epoch:0, Batch number 538
# Loss:0.37345045804977417, Epoch:0, Batch number 539
# Loss:0.21329264342784882, Epoch:0, Batch number 540
# Loss:0.24947702884674072, Epoch:0, Batch number 541
# Loss:0.3732964098453522, Epoch:0, Batch number 542
# Loss:0.2570110857486725, Epoch:0, Batch number 543
# Loss:0.20105092227458954, Epoch:0, Batch number 544
# Loss:0.21348105370998383, Epoch:0, Batch number 545
# Loss:0.18270644545555115, Epoch:0, Batch number 546
# Loss:0.2604653537273407, Epoch:0, Batch number 547
# Loss:0.3218193054199219, Epoch:0, Batch number 548
# Loss:0.2864372432231903, Epoch:0, Batch number 549
# Loss:0.17290346324443817, Epoch:0, Batch number 550
# Loss:0.2188681960105896, Epoch:0, Batch number 551
# Loss:0.23454983532428741, Epoch:0, Batch number 552
# Loss:0.4623276889324188, Epoch:0, Batch number 553
# Loss:0.3211868703365326, Epoch:0, Batch number 554
# Loss:0.3246416747570038, Epoch:0, Batch number 555
# Loss:0.1714298129081726, Epoch:0, Batch number 556
# Loss:0.31127238273620605, Epoch:0, Batch number 557
# Loss:0.5616660714149475, Epoch:0, Batch number 558
# Loss:0.42083701491355896, Epoch:0, Batch number 559
# Loss:0.4023911654949188, Epoch:0, Batch number 560
# Loss:0.23479227721691132, Epoch:0, Batch number 561
# Loss:0.21123433113098145, Epoch:0, Batch number 562
# Loss:0.34959298372268677, Epoch:0, Batch number 563
# Loss:0.3135170340538025, Epoch:0, Batch number 564
# Loss:0.21473613381385803, Epoch:0, Batch number 565
# Loss:0.2977190911769867, Epoch:0, Batch number 566
# Loss:0.5843972563743591, Epoch:0, Batch number 567
# Loss:0.31593388319015503, Epoch:0, Batch number 568
# Loss:0.22997024655342102, Epoch:0, Batch number 569
# Loss:0.2521897256374359, Epoch:0, Batch number 570
# Loss:0.20205363631248474, Epoch:0, Batch number 571
# Loss:0.21453957259655, Epoch:0, Batch number 572
# Loss:0.24615560472011566, Epoch:0, Batch number 573
# Loss:0.23874834179878235, Epoch:0, Batch number 574
# Loss:0.21288438141345978, Epoch:0, Batch number 575
# Loss:0.21640963852405548, Epoch:0, Batch number 576
# Loss:0.27093514800071716, Epoch:0, Batch number 577
# Loss:0.12639227509498596, Epoch:0, Batch number 578
# Loss:0.07409165799617767, Epoch:0, Batch number 579
# Loss:0.2353322058916092, Epoch:0, Batch number 580
# Loss:0.2748918831348419, Epoch:0, Batch number 581
# Loss:0.22239580750465393, Epoch:0, Batch number 582
# Loss:0.3007549047470093, Epoch:0, Batch number 583
# Loss:0.5434341430664062, Epoch:0, Batch number 584
# Loss:0.04832543805241585, Epoch:0, Batch number 585
# Loss:0.2220948487520218, Epoch:0, Batch number 586
# Loss:0.14362530410289764, Epoch:0, Batch number 587
# Loss:0.2106780707836151, Epoch:0, Batch number 588
# Loss:0.19919486343860626, Epoch:0, Batch number 589
# Loss:0.34026145935058594, Epoch:0, Batch number 590
# Loss:0.3596314489841461, Epoch:0, Batch number 591
# Loss:0.28625407814979553, Epoch:0, Batch number 592
# Loss:0.5833569169044495, Epoch:0, Batch number 593
# Loss:0.35701245069503784, Epoch:0, Batch number 594
# Loss:0.1740862876176834, Epoch:0, Batch number 595
# Loss:0.2662756145000458, Epoch:0, Batch number 596
# Loss:0.19463540613651276, Epoch:0, Batch number 597
# Loss:0.428711861371994, Epoch:0, Batch number 598
# Loss:0.18696336448192596, Epoch:0, Batch number 599
# Loss:0.2075563371181488, Epoch:0, Batch number 600
# Loss:0.2721177041530609, Epoch:0, Batch number 601
# Loss:0.40226972103118896, Epoch:0, Batch number 602
# Loss:0.2892293930053711, Epoch:0, Batch number 603
# Loss:0.2769567668437958, Epoch:0, Batch number 604
# Loss:0.42389529943466187, Epoch:0, Batch number 605
# Loss:0.1725190430879593, Epoch:0, Batch number 606
# Loss:0.22758834064006805, Epoch:0, Batch number 607
# Loss:0.1365986168384552, Epoch:0, Batch number 608
# Loss:0.5041051506996155, Epoch:0, Batch number 609
# Loss:0.25522658228874207, Epoch:0, Batch number 610
# Loss:0.3159962594509125, Epoch:0, Batch number 611
# Loss:0.16959485411643982, Epoch:0, Batch number 612
# Loss:0.3056848645210266, Epoch:0, Batch number 613
# Loss:0.3006250560283661, Epoch:0, Batch number 614
# Loss:0.12640069425106049, Epoch:0, Batch number 615
# Loss:0.22407782077789307, Epoch:0, Batch number 616
# Loss:0.44310927391052246, Epoch:0, Batch number 617
# Loss:0.3376923203468323, Epoch:0, Batch number 618
# Loss:0.4682809114456177, Epoch:0, Batch number 619
# Loss:0.21885307133197784, Epoch:0, Batch number 620
# Loss:0.2824306786060333, Epoch:0, Batch number 621
# Loss:0.10985501855611801, Epoch:0, Batch number 622
# Loss:0.2580498456954956, Epoch:0, Batch number 623
# Loss:0.43359699845314026, Epoch:0, Batch number 624
# Loss:0.16620983183383942, Epoch:0, Batch number 625
# Loss:0.4265201985836029, Epoch:0, Batch number 626
# Loss:0.26586076617240906, Epoch:0, Batch number 627
# Loss:0.3929324746131897, Epoch:0, Batch number 628
# Loss:0.24201394617557526, Epoch:0, Batch number 629
# Loss:0.5414007902145386, Epoch:0, Batch number 630
# Loss:0.25708508491516113, Epoch:0, Batch number 631
# Loss:0.24043278396129608, Epoch:0, Batch number 632
# Loss:0.29211103916168213, Epoch:0, Batch number 633
# Loss:0.15132038295269012, Epoch:0, Batch number 634
# Loss:0.23667368292808533, Epoch:0, Batch number 635
# Loss:0.2452520877122879, Epoch:0, Batch number 636
# Loss:0.3897198736667633, Epoch:0, Batch number 637
# Loss:0.2049548476934433, Epoch:0, Batch number 638
# Loss:0.2744637727737427, Epoch:0, Batch number 639
# Loss:0.2644275724887848, Epoch:0, Batch number 640
# Loss:0.2955392599105835, Epoch:0, Batch number 641
# Loss:0.3634675443172455, Epoch:0, Batch number 642
# Loss:0.4257241487503052, Epoch:0, Batch number 643
# Loss:0.3556576669216156, Epoch:0, Batch number 644
# Loss:0.18738126754760742, Epoch:0, Batch number 645
# Loss:0.29168227314949036, Epoch:0, Batch number 646
# Loss:0.34748706221580505, Epoch:0, Batch number 647
# Loss:0.23095522820949554, Epoch:0, Batch number 648
# Loss:0.24298685789108276, Epoch:0, Batch number 649
# Loss:0.3505137264728546, Epoch:0, Batch number 650
# Loss:0.24487687647342682, Epoch:0, Batch number 651
# Loss:0.10793836414813995, Epoch:0, Batch number 652
# Loss:0.18530569970607758, Epoch:0, Batch number 653
# Loss:0.19904547929763794, Epoch:0, Batch number 654
# Loss:0.17341063916683197, Epoch:0, Batch number 655
# Loss:0.11383580416440964, Epoch:0, Batch number 656
# Loss:0.22394849359989166, Epoch:0, Batch number 657
# Loss:0.2622176706790924, Epoch:0, Batch number 658
# Loss:0.1632336527109146, Epoch:0, Batch number 659
# Loss:0.17247703671455383, Epoch:0, Batch number 660
# Loss:0.24161206185817719, Epoch:0, Batch number 661
# Loss:0.17190974950790405, Epoch:0, Batch number 662
# Loss:0.2618599236011505, Epoch:0, Batch number 663
# Loss:0.06715963780879974, Epoch:0, Batch number 664
# Loss:0.27409178018569946, Epoch:0, Batch number 665
# Loss:0.15501877665519714, Epoch:0, Batch number 666
# Loss:0.2990238666534424, Epoch:0, Batch number 667
# Loss:0.4358152449131012, Epoch:0, Batch number 668
# Loss:0.2675231695175171, Epoch:0, Batch number 669
# Loss:0.25022998452186584, Epoch:0, Batch number 670
# Loss:0.17806708812713623, Epoch:0, Batch number 671
# Loss:0.13104590773582458, Epoch:0, Batch number 672
# Loss:0.2086009979248047, Epoch:0, Batch number 673
# Loss:0.22435761988162994, Epoch:0, Batch number 674
# Loss:0.34379103779792786, Epoch:0, Batch number 675
# Loss:0.6597611904144287, Epoch:0, Batch number 676
# Loss:0.260286808013916, Epoch:0, Batch number 677
# Loss:0.1399802267551422, Epoch:0, Batch number 678
# Loss:0.35703036189079285, Epoch:0, Batch number 679
# Loss:0.16792988777160645, Epoch:0, Batch number 680
# Loss:0.34049975872039795, Epoch:0, Batch number 681
# Loss:0.24765656888484955, Epoch:0, Batch number 682
# Loss:0.2343820184469223, Epoch:0, Batch number 683
# Loss:0.2559697926044464, Epoch:0, Batch number 684
# Loss:0.2555526793003082, Epoch:0, Batch number 685
# Loss:0.20419272780418396, Epoch:0, Batch number 686
# Loss:0.37995675206184387, Epoch:0, Batch number 687
# Loss:0.2683001160621643, Epoch:0, Batch number 688
# Loss:0.0519295409321785, Epoch:0, Batch number 689
# Loss:0.24583841860294342, Epoch:0, Batch number 690
# Loss:0.3588440716266632, Epoch:0, Batch number 691
# Loss:0.1841152012348175, Epoch:0, Batch number 692
# Loss:0.1298285871744156, Epoch:0, Batch number 693
# Loss:0.46724817156791687, Epoch:0, Batch number 694
# Loss:0.1746707409620285, Epoch:0, Batch number 695
# Loss:0.20244432985782623, Epoch:0, Batch number 696
# Loss:0.2435816526412964, Epoch:0, Batch number 697
# Loss:0.5282394289970398, Epoch:0, Batch number 698
# Loss:0.25731927156448364, Epoch:0, Batch number 699
# Loss:0.21620817482471466, Epoch:0, Batch number 700
# Loss:0.24894049763679504, Epoch:0, Batch number 701
# Loss:0.22131556272506714, Epoch:0, Batch number 702
# Loss:0.27183789014816284, Epoch:0, Batch number 703
# Loss:0.48703259229660034, Epoch:0, Batch number 704
# Loss:0.17452725768089294, Epoch:0, Batch number 705
# Loss:0.1826227456331253, Epoch:0, Batch number 706
# Loss:0.2819932699203491, Epoch:0, Batch number 707
# Loss:0.27589207887649536, Epoch:0, Batch number 708
# Loss:0.22435368597507477, Epoch:0, Batch number 709
# Loss:0.20661363005638123, Epoch:0, Batch number 710
# Loss:0.296379029750824, Epoch:0, Batch number 711
# Loss:0.2010035216808319, Epoch:0, Batch number 712
# Loss:0.3013766407966614, Epoch:0, Batch number 713
# Loss:0.19839593768119812, Epoch:0, Batch number 714
# Loss:0.28547370433807373, Epoch:0, Batch number 715
# Loss:0.13146786391735077, Epoch:0, Batch number 716
# Loss:0.28787747025489807, Epoch:0, Batch number 717
# Loss:0.33350417017936707, Epoch:0, Batch number 718
# Loss:0.3320460617542267, Epoch:0, Batch number 719
# Loss:0.18696272373199463, Epoch:0, Batch number 720
# Loss:0.26943543553352356, Epoch:0, Batch number 721
# Loss:0.19946934282779694, Epoch:0, Batch number 722
# Loss:0.42083272337913513, Epoch:0, Batch number 723
# Loss:0.2969209551811218, Epoch:0, Batch number 724
# Loss:0.20962636172771454, Epoch:0, Batch number 725
# Loss:0.2130669206380844, Epoch:0, Batch number 726
# Loss:0.29318228363990784, Epoch:0, Batch number 727
# Loss:0.19125299155712128, Epoch:0, Batch number 728
# Loss:0.5263274312019348, Epoch:0, Batch number 729
# Loss:0.11646690964698792, Epoch:0, Batch number 730
# Loss:0.23009280860424042, Epoch:0, Batch number 731
# Loss:0.2246685028076172, Epoch:0, Batch number 732
# Loss:0.3965296149253845, Epoch:0, Batch number 733
# Loss:0.1271800398826599, Epoch:0, Batch number 734
# Loss:0.2773590087890625, Epoch:0, Batch number 735
# Loss:0.15826793015003204, Epoch:0, Batch number 736
# Loss:0.40364596247673035, Epoch:0, Batch number 737
# Loss:0.19655616581439972, Epoch:0, Batch number 738
# Loss:0.1772891730070114, Epoch:0, Batch number 739
# Loss:0.12420959025621414, Epoch:0, Batch number 740
# Loss:0.20978352427482605, Epoch:0, Batch number 741
# Loss:0.33667558431625366, Epoch:0, Batch number 742
# Loss:0.1417675018310547, Epoch:0, Batch number 743
# Loss:0.3722746968269348, Epoch:0, Batch number 744
# Loss:0.1454973965883255, Epoch:0, Batch number 745
# Loss:0.23034271597862244, Epoch:0, Batch number 746
# Loss:0.14155511558055878, Epoch:0, Batch number 747
# Loss:0.4263512194156647, Epoch:0, Batch number 748
# Loss:0.34978175163269043, Epoch:0, Batch number 749
# Loss:0.14503160119056702, Epoch:0, Batch number 750
# Loss:0.1657671183347702, Epoch:0, Batch number 751
# Loss:0.30822235345840454, Epoch:0, Batch number 752
# Loss:0.13650405406951904, Epoch:0, Batch number 753
# Loss:0.3855377435684204, Epoch:0, Batch number 754
# Loss:0.17001822590827942, Epoch:0, Batch number 755
# Loss:0.3368211090564728, Epoch:0, Batch number 756
# Loss:0.17599116265773773, Epoch:0, Batch number 757
# Loss:0.21152269840240479, Epoch:0, Batch number 758
# Loss:0.281190425157547, Epoch:0, Batch number 759
# Loss:0.21951495110988617, Epoch:0, Batch number 760
# Loss:0.23876574635505676, Epoch:0, Batch number 761
# Loss:0.29009050130844116, Epoch:0, Batch number 762
# Loss:0.23831400275230408, Epoch:0, Batch number 763
# Loss:0.03580185025930405, Epoch:0, Batch number 764
# Loss:0.20618578791618347, Epoch:0, Batch number 765
# Loss:0.2833380103111267, Epoch:0, Batch number 766
# Loss:0.269530326128006, Epoch:0, Batch number 767
# Loss:0.1717233955860138, Epoch:0, Batch number 768
# Loss:0.24993346631526947, Epoch:0, Batch number 769
# Loss:0.09041234105825424, Epoch:0, Batch number 770
# Loss:0.2649633586406708, Epoch:0, Batch number 771
# Loss:0.2837255299091339, Epoch:0, Batch number 772
# Loss:0.10021388530731201, Epoch:0, Batch number 773
# Loss:0.3766191005706787, Epoch:0, Batch number 774
# Loss:0.27433109283447266, Epoch:0, Batch number 775
# Loss:0.21153251826763153, Epoch:0, Batch number 776
# Loss:0.1316056251525879, Epoch:0, Batch number 777
# Loss:0.19165797531604767, Epoch:0, Batch number 778
# Loss:0.2421317845582962, Epoch:0, Batch number 779
# Loss:0.2565412223339081, Epoch:0, Batch number 780
# Loss:0.38042426109313965, Epoch:0, Batch number 781
# Loss:0.3190890848636627, Epoch:0, Batch number 782
# Loss:0.21733970940113068, Epoch:0, Batch number 783
# Loss:0.20862461626529694, Epoch:0, Batch number 784
# Loss:0.3655502200126648, Epoch:0, Batch number 785
# Loss:0.2958070933818817, Epoch:0, Batch number 786
# Loss:0.2932409346103668, Epoch:0, Batch number 787
# Loss:0.14275996387004852, Epoch:0, Batch number 788
# Loss:0.3109102249145508, Epoch:0, Batch number 789
# Loss:0.21657443046569824, Epoch:0, Batch number 790
# Loss:0.17784841358661652, Epoch:0, Batch number 791
# Loss:0.21029725670814514, Epoch:0, Batch number 792
# Loss:0.2505771517753601, Epoch:0, Batch number 793
# Loss:0.36864641308784485, Epoch:0, Batch number 794
# Loss:0.1810738444328308, Epoch:0, Batch number 795
# Loss:0.18518801033496857, Epoch:0, Batch number 796
# Loss:0.30333247780799866, Epoch:0, Batch number 797
# Loss:0.28859350085258484, Epoch:0, Batch number 798
# Loss:0.15529419481754303, Epoch:0, Batch number 799
# Loss:0.2521389126777649, Epoch:0, Batch number 800
# Loss:0.11644068360328674, Epoch:0, Batch number 801
# Loss:0.3710010349750519, Epoch:0, Batch number 802
# Loss:0.15777286887168884, Epoch:0, Batch number 803
# Loss:0.3032045066356659, Epoch:0, Batch number 804
# Loss:0.6328144073486328, Epoch:0, Batch number 805
# Loss:0.2838660180568695, Epoch:0, Batch number 806
# Loss:0.09653393179178238, Epoch:0, Batch number 807
# Loss:0.15580309927463531, Epoch:0, Batch number 808
# Loss:0.3581487834453583, Epoch:0, Batch number 809
# Loss:0.15318244695663452, Epoch:0, Batch number 810
# Loss:0.27760785818099976, Epoch:0, Batch number 811
# Loss:0.22380556166172028, Epoch:0, Batch number 812
# Loss:0.1460219919681549, Epoch:0, Batch number 813
# Loss:0.22109827399253845, Epoch:0, Batch number 814
# Loss:0.21215616166591644, Epoch:0, Batch number 815
# Loss:0.21247445046901703, Epoch:0, Batch number 816
# Loss:0.09837496280670166, Epoch:0, Batch number 817
# Loss:0.12241322547197342, Epoch:0, Batch number 818
# Loss:0.1192614883184433, Epoch:0, Batch number 819
# Loss:0.15526048839092255, Epoch:0, Batch number 820
# Loss:0.26786333322525024, Epoch:0, Batch number 821
# Loss:0.098722442984581, Epoch:0, Batch number 822
# Loss:0.3101963996887207, Epoch:0, Batch number 823
# Loss:0.19820380210876465, Epoch:0, Batch number 824
# Loss:0.19727890193462372, Epoch:0, Batch number 825
# Loss:0.10976473242044449, Epoch:0, Batch number 826
# Loss:0.3695054352283478, Epoch:0, Batch number 827
# Loss:0.18312883377075195, Epoch:0, Batch number 828
# Loss:0.049865078181028366, Epoch:0, Batch number 829
# Loss:0.10052069276571274, Epoch:0, Batch number 830
# Loss:0.15138426423072815, Epoch:0, Batch number 831
# Loss:0.15934424102306366, Epoch:0, Batch number 832
# Loss:0.346222460269928, Epoch:0, Batch number 833
# Loss:0.2972349524497986, Epoch:0, Batch number 834
# Loss:0.33850353956222534, Epoch:0, Batch number 835
# Loss:0.14591218531131744, Epoch:0, Batch number 836
# Loss:0.09090292453765869, Epoch:0, Batch number 837
# Loss:0.6472334265708923, Epoch:0, Batch number 838
# Loss:0.1710251271724701, Epoch:0, Batch number 839
# Loss:0.13745397329330444, Epoch:0, Batch number 840
# Loss:0.31878283619880676, Epoch:0, Batch number 841
# Loss:0.22557906806468964, Epoch:0, Batch number 842
# Loss:0.18107207119464874, Epoch:0, Batch number 843
# Loss:0.2657434642314911, Epoch:0, Batch number 844
# Loss:0.2355329543352127, Epoch:0, Batch number 845
# Loss:0.2960589528083801, Epoch:0, Batch number 846
# Loss:0.2772325873374939, Epoch:0, Batch number 847
# Loss:0.11677098274230957, Epoch:0, Batch number 848
# Loss:0.3638494610786438, Epoch:0, Batch number 849
# Loss:0.33421072363853455, Epoch:0, Batch number 850
# Loss:0.10560637712478638, Epoch:0, Batch number 851
# Loss:0.13883443176746368, Epoch:0, Batch number 852
# Loss:0.12408219277858734, Epoch:0, Batch number 853
# Loss:0.2485722452402115, Epoch:0, Batch number 854
# Loss:0.11904150247573853, Epoch:0, Batch number 855
# Loss:0.20173870027065277, Epoch:0, Batch number 856
# Loss:0.20496943593025208, Epoch:0, Batch number 857
# Loss:0.1973780393600464, Epoch:0, Batch number 858
# Loss:0.19789926707744598, Epoch:0, Batch number 859
# Loss:0.19350162148475647, Epoch:0, Batch number 860
# Loss:0.2589888274669647, Epoch:0, Batch number 861
# Loss:0.3248182237148285, Epoch:0, Batch number 862
# Loss:0.12410333007574081, Epoch:0, Batch number 863
# Loss:0.14256370067596436, Epoch:0, Batch number 864
# Loss:0.257694810628891, Epoch:0, Batch number 865
# Loss:0.4537448585033417, Epoch:0, Batch number 866
# Loss:0.4376654326915741, Epoch:0, Batch number 867
# Loss:0.23992294073104858, Epoch:0, Batch number 868
# Loss:0.20634587109088898, Epoch:0, Batch number 869
# Loss:0.2425127476453781, Epoch:0, Batch number 870
# Loss:0.464827299118042, Epoch:0, Batch number 871
# Loss:0.23379534482955933, Epoch:0, Batch number 872
# Loss:0.1941515952348709, Epoch:0, Batch number 873
# Loss:0.26352357864379883, Epoch:0, Batch number 874
# Loss:0.19679883122444153, Epoch:0, Batch number 875
# Loss:0.21354281902313232, Epoch:0, Batch number 876
# Loss:0.25876370072364807, Epoch:0, Batch number 877
# Loss:0.14737604558467865, Epoch:0, Batch number 878
# Loss:0.28624075651168823, Epoch:0, Batch number 879
# Loss:0.4819628596305847, Epoch:0, Batch number 880
# Loss:0.21422526240348816, Epoch:0, Batch number 881
# Loss:0.1787235289812088, Epoch:0, Batch number 882
# Loss:0.2508827745914459, Epoch:0, Batch number 883
# Loss:0.1211916133761406, Epoch:0, Batch number 884
# Loss:0.1716565489768982, Epoch:0, Batch number 885
# Loss:0.17221784591674805, Epoch:0, Batch number 886
# Loss:0.08498310297727585, Epoch:0, Batch number 887
# Loss:0.17349642515182495, Epoch:0, Batch number 888
# Loss:0.18926002085208893, Epoch:0, Batch number 889
# Loss:0.1470746397972107, Epoch:0, Batch number 890
# Loss:0.34507784247398376, Epoch:0, Batch number 891
# Loss:0.16766813397407532, Epoch:0, Batch number 892
# Loss:0.145553320646286, Epoch:0, Batch number 893
# Loss:0.16300293803215027, Epoch:0, Batch number 894
# Loss:0.4645223617553711, Epoch:0, Batch number 895
# Loss:0.35964837670326233, Epoch:0, Batch number 896
# Loss:0.28015196323394775, Epoch:0, Batch number 897
# Loss:0.4018370807170868, Epoch:0, Batch number 898
# Loss:0.17528261244297028, Epoch:0, Batch number 899
# Loss:0.26539117097854614, Epoch:0, Batch number 900
# Loss:0.4832982122898102, Epoch:0, Batch number 901
# Loss:0.3049617111682892, Epoch:0, Batch number 902
# Loss:0.17167794704437256, Epoch:0, Batch number 903
# Loss:0.14568714797496796, Epoch:0, Batch number 904
# Loss:0.17406585812568665, Epoch:0, Batch number 905
# Loss:0.2862001359462738, Epoch:0, Batch number 906
# Loss:0.17320296168327332, Epoch:0, Batch number 907
# Loss:0.31111061573028564, Epoch:0, Batch number 908
# Loss:0.2245459407567978, Epoch:0, Batch number 909
# Loss:0.23665505647659302, Epoch:0, Batch number 910
# Loss:0.17294800281524658, Epoch:0, Batch number 911
# Loss:0.10209241509437561, Epoch:0, Batch number 912
# Loss:0.25793495774269104, Epoch:0, Batch number 913
# Loss:0.20750737190246582, Epoch:0, Batch number 914
# Loss:0.13405174016952515, Epoch:0, Batch number 915
# Loss:0.20341572165489197, Epoch:0, Batch number 916
# Loss:0.1351998895406723, Epoch:0, Batch number 917
# Loss:0.173736572265625, Epoch:0, Batch number 918
# Loss:0.18571607768535614, Epoch:0, Batch number 919
# Loss:0.44393351674079895, Epoch:0, Batch number 920
# Loss:0.1404305249452591, Epoch:0, Batch number 921
# Loss:0.21470196545124054, Epoch:0, Batch number 922
# Loss:0.4461684226989746, Epoch:0, Batch number 923
# Loss:0.1887919306755066, Epoch:0, Batch number 924
# Loss:0.3305184245109558, Epoch:0, Batch number 925
# Loss:0.17787505686283112, Epoch:0, Batch number 926
# Loss:0.2804306745529175, Epoch:0, Batch number 927
# Loss:0.16467802226543427, Epoch:0, Batch number 928
# Loss:0.32887905836105347, Epoch:0, Batch number 929
# Loss:0.3028052747249603, Epoch:0, Batch number 930
# Loss:0.29006198048591614, Epoch:0, Batch number 931
# Loss:0.09159277379512787, Epoch:0, Batch number 932
# Loss:0.1399926245212555, Epoch:0, Batch number 933
# ...
# Loss:0.25856369733810425, Epoch:1, Batch number 1142
# Loss:0.10774513334035873, Epoch:1, Batch number 1143
# Loss:0.26104840636253357, Epoch:1, Batch number 1144
# Loss:0.2192719727754593, Epoch:1, Batch number 1145
# Loss:0.4639888107776642, Epoch:1, Batch number 1146
# Loss:0.20693407952785492, Epoch:1, Batch number 1147
# Loss:0.19999240338802338, Epoch:1, Batch number 1148
# Loss:0.15389080345630646, Epoch:1, Batch number 1149
# Loss:0.12590579688549042, Epoch:1, Batch number 1150
# Loss:0.1638050526380539, Epoch:1, Batch number 1151
# Loss:0.1544082909822464, Epoch:1, Batch number 1152
# Loss:0.16181565821170807, Epoch:1, Batch number 1153
# Loss:0.16900603473186493, Epoch:1, Batch number 1154
# Loss:0.19227555394172668, Epoch:1, Batch number 1155
# Loss:0.14964017271995544, Epoch:1, Batch number 1156
# Loss:0.17619912326335907, Epoch:1, Batch number 1157
# Loss:0.07068215310573578, Epoch:1, Batch number 1158
# Loss:0.22029782831668854, Epoch:1, Batch number 1159
# Loss:0.09035702794790268, Epoch:1, Batch number 1160
# Loss:0.12659308314323425, Epoch:1, Batch number 1161
# Loss:0.14998069405555725, Epoch:1, Batch number 1162
# Loss:0.1391756534576416, Epoch:1, Batch number 1163
# Loss:0.37106505036354065, Epoch:1, Batch number 1164
# Loss:0.09094922989606857, Epoch:1, Batch number 1165
# Loss:0.18412649631500244, Epoch:1, Batch number 1166
# Loss:0.38320252299308777, Epoch:1, Batch number 1167
# Loss:0.1675150990486145, Epoch:1, Batch number 1168
# Loss:0.1130690649151802, Epoch:1, Batch number 1169
# Loss:0.18442538380622864, Epoch:1, Batch number 1170
# Loss:0.09468910098075867, Epoch:1, Batch number 1171
# Loss:0.0894717276096344, Epoch:1, Batch number 1172
# Loss:0.13519003987312317, Epoch:1, Batch number 1173
# Loss:0.3025079369544983, Epoch:1, Batch number 1174
# Loss:0.11573219299316406, Epoch:1, Batch number 1175
# Loss:0.29377204179763794, Epoch:1, Batch number 1176
# Loss:0.13076820969581604, Epoch:1, Batch number 1177
# Loss:0.0674610286951065, Epoch:1, Batch number 1178
# Loss:0.19966056942939758, Epoch:1, Batch number 1179
# Loss:0.41959309577941895, Epoch:1, Batch number 1180
# Loss:0.1315336674451828, Epoch:1, Batch number 1181
# Loss:0.18761000037193298, Epoch:1, Batch number 1182
# Loss:0.13251110911369324, Epoch:1, Batch number 1183
# Loss:0.13397811353206635, Epoch:1, Batch number 1184
# Loss:0.09673143178224564, Epoch:1, Batch number 1185
# Loss:0.2894206643104553, Epoch:1, Batch number 1186
# Loss:0.03349059820175171, Epoch:1, Batch number 1187
# Loss:0.2086794227361679, Epoch:1, Batch number 1188
# Loss:0.11112212389707565, Epoch:1, Batch number 1189
# Loss:0.2815878391265869, Epoch:1, Batch number 1190
# Loss:0.13523541390895844, Epoch:1, Batch number 1191
# Loss:0.1151750385761261, Epoch:1, Batch number 1192
# Loss:0.051696375012397766, Epoch:1, Batch number 1193
# Loss:0.1407729834318161, Epoch:1, Batch number 1194
# Loss:0.1406138390302658, Epoch:1, Batch number 1195
# Loss:0.19766181707382202, Epoch:1, Batch number 1196
# Loss:0.07814469933509827, Epoch:1, Batch number 1197
# Loss:0.16522105038166046, Epoch:1, Batch number 1198
# Loss:0.2118089199066162, Epoch:1, Batch number 1199
# Loss:0.17136460542678833, Epoch:1, Batch number 1200
# Loss:0.12308172881603241, Epoch:1, Batch number 1201
# Loss:0.26612383127212524, Epoch:1, Batch number 1202
# Loss:0.12215631455183029, Epoch:1, Batch number 1203
# Loss:0.1234026849269867, Epoch:1, Batch number 1204
# Loss:0.24744254350662231, Epoch:1, Batch number 1205
# Loss:0.13308733701705933, Epoch:1, Batch number 1206
# Loss:0.12232167273759842, Epoch:1, Batch number 1207
# Loss:0.059140514582395554, Epoch:1, Batch number 1208
# Loss:0.16206201910972595, Epoch:1, Batch number 1209
# Loss:0.0774444118142128, Epoch:1, Batch number 1210
# Loss:0.2633111774921417, Epoch:1, Batch number 1211
# Loss:0.16036897897720337, Epoch:1, Batch number 1212
# Loss:0.14606323838233948, Epoch:1, Batch number 1213
# Loss:0.119851253926754, Epoch:1, Batch number 1214
# Loss:0.12583225965499878, Epoch:1, Batch number 1215
# Loss:0.07803375273942947, Epoch:1, Batch number 1216
# Loss:0.1910545825958252, Epoch:1, Batch number 1217
# Loss:0.24659192562103271, Epoch:1, Batch number 1218
# Loss:0.09941361099481583, Epoch:1, Batch number 1219
# Loss:0.21023710072040558, Epoch:1, Batch number 1220
# Loss:0.1498202383518219, Epoch:1, Batch number 1221
# Loss:0.0955388993024826, Epoch:1, Batch number 1222
# Loss:0.20878298580646515, Epoch:1, Batch number 1223
# Loss:0.13650478422641754, Epoch:1, Batch number 1224
# Loss:0.15114711225032806, Epoch:1, Batch number 1225
# Loss:0.08130846917629242, Epoch:1, Batch number 1226
# Loss:0.04272111505270004, Epoch:1, Batch number 1227
# Loss:0.28378385305404663, Epoch:1, Batch number 1228
# Loss:0.2167673408985138, Epoch:1, Batch number 1229
# Loss:0.12488808482885361, Epoch:1, Batch number 1230
# Loss:0.08859540522098541, Epoch:1, Batch number 1231
# Loss:0.0922975018620491, Epoch:1, Batch number 1232
# Loss:0.05558132752776146, Epoch:1, Batch number 1233
# Loss:0.19579903781414032, Epoch:1, Batch number 1234
# Loss:0.14302439987659454, Epoch:1, Batch number 1235
# Loss:0.13929903507232666, Epoch:1, Batch number 1236
# Loss:0.20582938194274902, Epoch:1, Batch number 1237
# Loss:0.10122338682413101, Epoch:1, Batch number 1238
# Loss:0.4174516797065735, Epoch:1, Batch number 1239
# Loss:0.10083426535129547, Epoch:1, Batch number 1240
# Loss:0.11415296792984009, Epoch:1, Batch number 1241
# Loss:0.18876488506793976, Epoch:1, Batch number 1242
# Loss:0.29113471508026123, Epoch:1, Batch number 1243
# Loss:0.03906361758708954, Epoch:1, Batch number 1244
# Loss:0.166927307844162, Epoch:1, Batch number 1245
# Loss:0.14482416212558746, Epoch:1, Batch number 1246
# Loss:0.10868357121944427, Epoch:1, Batch number 1247
# Loss:0.1575874388217926, Epoch:1, Batch number 1248
# Loss:0.1255607008934021, Epoch:1, Batch number 1249
# Loss:0.15442456305027008, Epoch:1, Batch number 1250
# Loss:0.23949770629405975, Epoch:1, Batch number 1251
# Loss:0.15172260999679565, Epoch:1, Batch number 1252
# Loss:0.25389620661735535, Epoch:1, Batch number 1253
# Loss:0.08902456611394882, Epoch:1, Batch number 1254
# Loss:0.05694522336125374, Epoch:1, Batch number 1255
# Loss:0.25858503580093384, Epoch:1, Batch number 1256
# Loss:0.13725586235523224, Epoch:1, Batch number 1257
# Loss:0.0962635800242424, Epoch:1, Batch number 1258
# Loss:0.035693276673555374, Epoch:1, Batch number 1259
# Loss:0.2267601490020752, Epoch:1, Batch number 1260
# Loss:0.1435553878545761, Epoch:1, Batch number 1261
# Loss:0.17667286098003387, Epoch:1, Batch number 1262
# Loss:0.1407671868801117, Epoch:1, Batch number 1263
# Loss:0.11002563685178757, Epoch:1, Batch number 1264
# Loss:0.10100233554840088, Epoch:1, Batch number 1265
# Loss:0.14887528121471405, Epoch:1, Batch number 1266
# Loss:0.20308250188827515, Epoch:1, Batch number 1267
# Loss:0.09627173095941544, Epoch:1, Batch number 1268
# Loss:0.07223041355609894, Epoch:1, Batch number 1269
# Loss:0.1280026137828827, Epoch:1, Batch number 1270
# Loss:0.2655772268772125, Epoch:1, Batch number 1271
# Loss:0.24338825047016144, Epoch:1, Batch number 1272
# Loss:0.14830975234508514, Epoch:1, Batch number 1273
# Loss:0.08896538615226746, Epoch:1, Batch number 1274
# Loss:0.3214438557624817, Epoch:1, Batch number 1275
# Loss:0.08459249883890152, Epoch:1, Batch number 1276
# Loss:0.12352103739976883, Epoch:1, Batch number 1277
# Loss:0.1790057271718979, Epoch:1, Batch number 1278
# Loss:0.060790542513132095, Epoch:1, Batch number 1279
# Loss:0.08415296673774719, Epoch:1, Batch number 1280
# Loss:0.10010186582803726, Epoch:1, Batch number 1281
# Loss:0.17136195302009583, Epoch:1, Batch number 1282
# Loss:0.09030436724424362, Epoch:1, Batch number 1283
# Loss:0.22015535831451416, Epoch:1, Batch number 1284
# Loss:0.060942430049180984, Epoch:1, Batch number 1285
# Loss:0.24560269713401794, Epoch:1, Batch number 1286
# Loss:0.18741998076438904, Epoch:1, Batch number 1287
# Loss:0.10774168372154236, Epoch:1, Batch number 1288
# Loss:0.28513863682746887, Epoch:1, Batch number 1289
# Loss:0.09513118118047714, Epoch:1, Batch number 1290
# Loss:0.09417740255594254, Epoch:1, Batch number 1291
# Loss:0.08510960638523102, Epoch:1, Batch number 1292
# Loss:0.06113576143980026, Epoch:1, Batch number 1293
# Loss:0.23710449039936066, Epoch:1, Batch number 1294
# Loss:0.20350053906440735, Epoch:1, Batch number 1295
# Loss:0.20483048260211945, Epoch:1, Batch number 1296
# Loss:0.20183861255645752, Epoch:1, Batch number 1297
# Loss:0.20058147609233856, Epoch:1, Batch number 1298
# Loss:0.1258224993944168, Epoch:1, Batch number 1299
# Loss:0.05719368904829025, Epoch:1, Batch number 1300
# Loss:0.1452694535255432, Epoch:1, Batch number 1301
# Loss:0.0634027048945427, Epoch:1, Batch number 1302
# Loss:0.09347648918628693, Epoch:1, Batch number 1303
# Loss:0.19064584374427795, Epoch:1, Batch number 1304
# Loss:0.23664405941963196, Epoch:1, Batch number 1305
# Loss:0.15827184915542603, Epoch:1, Batch number 1306
# Loss:0.2695159316062927, Epoch:1, Batch number 1307
# Loss:0.1729152351617813, Epoch:1, Batch number 1308
# Loss:0.11809433251619339, Epoch:1, Batch number 1309
# Loss:0.2736460268497467, Epoch:1, Batch number 1310
# Loss:0.09660620987415314, Epoch:1, Batch number 1311
# Loss:0.15992523729801178, Epoch:1, Batch number 1312
# Loss:0.08444561064243317, Epoch:1, Batch number 1313
# Loss:0.11893108487129211, Epoch:1, Batch number 1314
# Loss:0.22700616717338562, Epoch:1, Batch number 1315
# Loss:0.2186294049024582, Epoch:1, Batch number 1316
# Loss:0.06818386167287827, Epoch:1, Batch number 1317
# Loss:0.1500362902879715, Epoch:1, Batch number 1318
# Loss:0.10485203564167023, Epoch:1, Batch number 1319
# Loss:0.1048128753900528, Epoch:1, Batch number 1320
# Loss:0.2041677087545395, Epoch:1, Batch number 1321
# Loss:0.1651310920715332, Epoch:1, Batch number 1322
# Loss:0.050334956496953964, Epoch:1, Batch number 1323
# Loss:0.21380895376205444, Epoch:1, Batch number 1324
# Loss:0.12934176623821259, Epoch:1, Batch number 1325
# Loss:0.07362275570631027, Epoch:1, Batch number 1326
# Loss:0.13386617600917816, Epoch:1, Batch number 1327
# Loss:0.23359714448451996, Epoch:1, Batch number 1328
# Loss:0.05474305525422096, Epoch:1, Batch number 1329
# Loss:0.2546122074127197, Epoch:1, Batch number 1330
# Loss:0.24987465143203735, Epoch:1, Batch number 1331
# Loss:0.18389374017715454, Epoch:1, Batch number 1332
# Loss:0.2663998305797577, Epoch:1, Batch number 1333
# Loss:0.1790393888950348, Epoch:1, Batch number 1334
# Loss:0.45729145407676697, Epoch:1, Batch number 1335
# Loss:0.19126492738723755, Epoch:1, Batch number 1336
# Loss:0.10190792381763458, Epoch:1, Batch number 1337
# Loss:0.15722019970417023, Epoch:1, Batch number 1338
# Loss:0.1622839719057083, Epoch:1, Batch number 1339
# Loss:0.12067792564630508, Epoch:1, Batch number 1340
# Loss:0.14938780665397644, Epoch:1, Batch number 1341
# Loss:0.2502048909664154, Epoch:1, Batch number 1342
# Loss:0.20689845085144043, Epoch:1, Batch number 1343
# Loss:0.11845800280570984, Epoch:1, Batch number 1344
# Loss:0.18056385219097137, Epoch:1, Batch number 1345
# Loss:0.14982229471206665, Epoch:1, Batch number 1346
# Loss:0.19571512937545776, Epoch:1, Batch number 1347
# Loss:0.21406632661819458, Epoch:1, Batch number 1348
# Loss:0.10989943891763687, Epoch:1, Batch number 1349
# Loss:0.15674905478954315, Epoch:1, Batch number 1350
# Loss:0.1511773318052292, Epoch:1, Batch number 1351
# Loss:0.09767888486385345, Epoch:1, Batch number 1352
# Loss:0.17303715646266937, Epoch:1, Batch number 1353
# Loss:0.06749050319194794, Epoch:1, Batch number 1354
# Loss:0.1492510735988617, Epoch:1, Batch number 1355
# Loss:0.07346946001052856, Epoch:1, Batch number 1356
# Loss:0.13480883836746216, Epoch:1, Batch number 1357
# Loss:0.14875316619873047, Epoch:1, Batch number 1358
# Loss:0.10002864897251129, Epoch:1, Batch number 1359
# Loss:0.0877663791179657, Epoch:1, Batch number 1360
# Loss:0.1756124049425125, Epoch:1, Batch number 1361
# Loss:0.12354747951030731, Epoch:1, Batch number 1362
# Loss:0.1642816811800003, Epoch:1, Batch number 1363
# Loss:0.12503576278686523, Epoch:1, Batch number 1364
# Loss:0.08861219882965088, Epoch:1, Batch number 1365
# Loss:0.07817688584327698, Epoch:1, Batch number 1366
# Loss:0.04597170650959015, Epoch:1, Batch number 1367
# Loss:0.17473122477531433, Epoch:1, Batch number 1368
# Loss:0.013835655525326729, Epoch:1, Batch number 1369
# Loss:0.2605307698249817, Epoch:1, Batch number 1370
# Loss:0.11064217984676361, Epoch:1, Batch number 1371
# Loss:0.23842468857765198, Epoch:1, Batch number 1372
# Loss:0.16814611852169037, Epoch:1, Batch number 1373
# Loss:0.09215354919433594, Epoch:1, Batch number 1374
# Loss:0.09912574291229248, Epoch:1, Batch number 1375
# Loss:0.10294091701507568, Epoch:1, Batch number 1376
# Loss:0.21501538157463074, Epoch:1, Batch number 1377
# Loss:0.07309592515230179, Epoch:1, Batch number 1378
# Loss:0.15995560586452484, Epoch:1, Batch number 1379
# Loss:0.2116049975156784, Epoch:1, Batch number 1380
# Loss:0.13008910417556763, Epoch:1, Batch number 1381
# Loss:0.3349256217479706, Epoch:1, Batch number 1382
# Loss:0.25195765495300293, Epoch:1, Batch number 1383
# Loss:0.10858862102031708, Epoch:1, Batch number 1384
# Loss:0.14072024822235107, Epoch:1, Batch number 1385
# Loss:0.27394285798072815, Epoch:1, Batch number 1386
# Loss:0.048885393887758255, Epoch:1, Batch number 1387
# Loss:0.13532193005084991, Epoch:1, Batch number 1388
# Loss:0.2712629735469818, Epoch:1, Batch number 1389
# Loss:0.32251790165901184, Epoch:1, Batch number 1390
# Loss:0.31963542103767395, Epoch:1, Batch number 1391
# Loss:0.09068474173545837, Epoch:1, Batch number 1392
# Loss:0.19419901072978973, Epoch:1, Batch number 1393
# Loss:0.0702282190322876, Epoch:1, Batch number 1394
# Loss:0.23972484469413757, Epoch:1, Batch number 1395
# Loss:0.11519555002450943, Epoch:1, Batch number 1396
# Loss:0.12178903818130493, Epoch:1, Batch number 1397
# Loss:0.1430596262216568, Epoch:1, Batch number 1398
# Loss:0.07170576602220535, Epoch:1, Batch number 1399
# Loss:0.2281440794467926, Epoch:1, Batch number 1400
# Loss:0.20794905722141266, Epoch:1, Batch number 1401
# Loss:0.17481300234794617, Epoch:1, Batch number 1402
# Loss:0.09323461353778839, Epoch:1, Batch number 1403
# Loss:0.13055522739887238, Epoch:1, Batch number 1404
# Loss:0.2055257260799408, Epoch:1, Batch number 1405
# Loss:0.12002460658550262, Epoch:1, Batch number 1406
# Loss:0.16767443716526031, Epoch:1, Batch number 1407
# Loss:0.12019491195678711, Epoch:1, Batch number 1408
# Loss:0.15775135159492493, Epoch:1, Batch number 1409
# Loss:0.1070033460855484, Epoch:1, Batch number 1410
# Loss:0.12310230731964111, Epoch:1, Batch number 1411
# Loss:0.13786254823207855, Epoch:1, Batch number 1412
# Loss:0.12880884110927582, Epoch:1, Batch number 1413
# Loss:0.1711154282093048, Epoch:1, Batch number 1414
# Loss:0.05523192137479782, Epoch:1, Batch number 1415
# Loss:0.08006720244884491, Epoch:1, Batch number 1416
# Loss:0.16543801128864288, Epoch:1, Batch number 1417
# Loss:0.14552512764930725, Epoch:1, Batch number 1418
# Loss:0.036261267960071564, Epoch:1, Batch number 1419
# Loss:0.1309964954853058, Epoch:1, Batch number 1420
# Loss:0.05360626429319382, Epoch:1, Batch number 1421
# Loss:0.21194197237491608, Epoch:1, Batch number 1422
# Loss:0.2744676172733307, Epoch:1, Batch number 1423
# Loss:0.1440093070268631, Epoch:1, Batch number 1424
# Loss:0.17025642096996307, Epoch:1, Batch number 1425
# Loss:0.3891660273075104, Epoch:1, Batch number 1426
# Loss:0.37315815687179565, Epoch:1, Batch number 1427
# Loss:0.1622101217508316, Epoch:1, Batch number 1428
# Loss:0.15634359419345856, Epoch:1, Batch number 1429
# Loss:0.207340806722641, Epoch:1, Batch number 1430
# Loss:0.07521198689937592, Epoch:1, Batch number 1431
# Loss:0.1114695742726326, Epoch:1, Batch number 1432
# Loss:0.10737805813550949, Epoch:1, Batch number 1433
# Loss:0.1265227496623993, Epoch:1, Batch number 1434
# Loss:0.09711390733718872, Epoch:1, Batch number 1435
# Loss:0.24827934801578522, Epoch:1, Batch number 1436
# Loss:0.10099377483129501, Epoch:1, Batch number 1437
# Loss:0.09100157767534256, Epoch:1, Batch number 1438
# Loss:0.19827872514724731, Epoch:1, Batch number 1439
# Loss:0.123209148645401, Epoch:1, Batch number 1440
# Loss:0.1311875879764557, Epoch:1, Batch number 1441
# Loss:0.131841778755188, Epoch:1, Batch number 1442
# Loss:0.13399632275104523, Epoch:1, Batch number 1443
# Loss:0.03466968983411789, Epoch:1, Batch number 1444

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import numpy
import matplotlib.pyplot as plt

alpha = 20
nusers = 5
ndata = 26

diri = numpy.random.dirichlet([alpha]*nusers , ndata).transpose()

plt.barh(range(26), diri[0])
plt.barh(range(26), diri[1], left=diri[0], color='g')
plt.barh(range(26), diri[2], left=diri[0]+diri[1], color='r')
plt.barh(range(26), diri[3], left=diri[0]+diri[1]+diri[2], color='y')
plt.barh(range(26), diri[4], left=diri[0]+diri[1]+diri[2]+diri[3], color='black')

print(diri)
# Out:
# [[0.15889933 0.12144232 0.14014445 0.17996855 0.26012571 0.16794575
#   0.15274504 0.14585389 0.19707153 0.26719777 0.14176413 0.13900579
#   0.1776931  0.25675788 0.15144484 0.19340744 0.18649539 0.20423904
#   0.25213028 0.22318198 0.16064716 0.12856712 0.17858317 0.22013824
#   0.22323808 0.17716852]
#  [0.13583953 0.19486976 0.17917616 0.19906453 0.17175404 0.24957051
#   0.21314812 0.27772409 0.16614478 0.19192421 0.25688249 0.23246732
#   0.1897714  0.18289058 0.31250935 0.20876722 0.15381319 0.19727424
#   0.21152567 0.23333855 0.20265348 0.22350844 0.17475559 0.18005254
#   0.20886505 0.17570289]
#  [0.28096445 0.29559389 0.16722939 0.23881786 0.17761709 0.15510348
#   0.15852689 0.176945   0.23143963 0.24503446 0.16941037 0.23154009
#   0.1655153  0.2068195  0.18725474 0.24412946 0.20688013 0.18096198
#   0.17088384 0.19011401 0.22348987 0.20558958 0.11671288 0.19012634
#   0.18605793 0.15870001]
#  [0.27242256 0.21286558 0.32166573 0.17752901 0.16865293 0.24124172
#   0.19497196 0.16130922 0.25628575 0.14783049 0.16761344 0.2111937
#   0.24960222 0.17967752 0.17993824 0.18046094 0.20709717 0.24785281
#   0.18674508 0.14842437 0.24041683 0.23401145 0.32483518 0.20912889
#   0.12880151 0.24526598]
#  [0.15187412 0.17522846 0.19178427 0.20462005 0.22185022 0.18613854
#   0.28060799 0.23816779 0.14905831 0.14801308 0.26432956 0.18579309
#   0.21741797 0.17385451 0.16885281 0.17323495 0.24571413 0.16967193
#   0.17871513 0.20494109 0.17279266 0.20832341 0.20511319 0.20055399
#   0.25303743 0.2431626 ]]

# %%
print(diri[0,0]+diri[1,0]+diri[2,0]+diri[3,0]+diri[4,0])
# Out:
# 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Subset

trainDict = {}
subsetDict = {}
labels = train_dataset.targets
numbersRg = list(range(0,25))
for i in numbersRg:
  trainDict['train{0}'.format(i)] = []

for j in numbersRg:
  for i in range(len(labels)):
    tensor = "tensor(" + str(j) + ")"
    if str(labels[i]) == tensor:
      trainDict['train{0}'.format(j)].append(i)

for i in numbersRg:
   subsetDict['subset{0}'.format(i)] = Subset(train_dataset, trainDict['train{0}'.format(i)])

figure = plt.figure(figsize=(10, 8))
cols, rows = 5, 5
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(subsetDict['subset5']), size=(1,)).item()
    img, label = subsetDict['subset5'][sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(label)
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
from torch.utils.data import ConcatDataset

clientDict = {}
clientSetDict = {}
sizeDatasets = {}
sizeDatasetsClients = {}
subsetsNestDict = {}
labels = train_dataset.targets
numberClients = list(range(nusers))
print(numberClients)
for j in numberClients:
  clientDict['client{0}set'.format(j+1)] = []

for i in numbersRg:
  sizeDatasets['n{0}'.format(i)] = len(subsetDict['subset{0}'.format(i)])
  for j in numberClients:
    if j == 0:
      newRg = 0
      lastRg = 0
    sizeDatasetsClients['n' + str(i) + '_client' + str(j)] = int(diri[j,i] * sizeDatasets['n{0}'.format(i)])
    newRg += sizeDatasetsClients['n' + str(i) + '_client' + str(j)]
    diricSize = range(lastRg, newRg)
    #print(diricSize)
    lastRg = newRg + 1
    subsetsNestDict['client' + str(j) + '_set' + str(i)] = Subset(subsetDict['subset{0}'.format(i)], diricSize)
    clientDict['client{0}set'.format(j+1)].extend(subsetsNestDict['client' + str(j) + '_set' + str(i)])


figure = plt.figure(figsize=(10, 8))
cols, rows = 5, 5
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(clientDict['client4set']), size=(1,)).item()
    img, label = clientDict['client4set'][sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(label)
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

print(len(clientDict['client1set']))
print(len(clientDict['client2set']))
print(len(clientDict['client3set']))
print(len(clientDict['client4set']))
print(len(clientDict['client5set']))
# Out:
# [0, 1, 2, 3, 4]
# 21444
# 24025
# 22628
# 23860
# 23088

# %%
#devices

deviceList = {}

for j in numberClients:
  deviceList['device{0}'.format(j+1)] = get_default_device()

deviceGlobal = get_default_device()

# %%
from time import time
from torch.utils.data import DataLoader
import torch.optim as optim

#Make a global model


def mainFL():
    
    ## You can play with these parameters & observe how they effect the training process.
    learning_rate = 0.001
    batch_size = 64 # It has to be lower due to a lower number of data
    epochs = 10 # Not very important after 5 in centralised, important for FL

    
    ## instantiate your nets a datasets
    net1 = EmnistModel()
    net1.to(deviceList['device1'])
    net2 = EmnistModel()
    net2.to(deviceList['device2'])
    net3 = EmnistModel()
    net3.to(deviceList['device3'])
    net4 = EmnistModel()
    net4.to(deviceList['device4'])
    net5 = EmnistModel()
    net5.to(deviceList['device5'])
    netGlobal = EmnistModel()
    netGlobal.to(deviceGlobal)
    netList = [net1, net2, net3, net4, net5]
    datasetList = [clientDict['client1set'], clientDict['client2set'], clientDict['client3set'], clientDict['client4set'], clientDict['client5set']]
    tupleData = list(zip(netList,datasetList))
    clients = [0,1,2,3,4]

    testloader = DataLoader(test_dataset, batch_size, num_workers = 2, shuffle = True, pin_memory=True)
         
    time0 = time()

    for epoch in range(epochs):
      net_dict = {}
      criterion = nn.CrossEntropyLoss()
      for index,(i,j) in enumerate(tupleData):          
          ## create dataloaders for each user (train) to load data into batches
          trainloader = DataLoader(j, batch_size, num_workers = 2, shuffle = True, pin_memory=True)
          
          ## Send data to GPU
          train_loader = DeviceDataLoader(trainloader, deviceList['device{0}'.format(index+1)])
          test_loader = DeviceDataLoader(testloader, deviceList['device{0}'.format(index+1)])
          ## instantiate an optimizer for you model, as well as a criterion/loss function - SGD         
          optimizer = optim.Adam(i.parameters(), lr= learning_rate)
    
          # Evaluating the model before any training steps is a good practice
          accuracy, loss = test(i, criterion, test_loader)
          print('Before training :',f'Accuracy: {accuracy}', f'Loss: {loss}',f'Client {index+1}' )
           
          train(epoch, i, optimizer, criterion, train_loader)
          accuracy, loss = test(i, criterion, test_loader)
          net_dict[index] = i
          print('After training :',f'Accuracy: {accuracy}', f'Loss: {loss}',f'Client {index+1}' )
  
      test_loader_global = DeviceDataLoader(testloader, deviceGlobal)
      netGlobal = aggregrate_models(net_dict, netGlobal, clients)
      for model, _ in tupleData:
        model.load_state_dict(netGlobal.state_dict())
      accuracy, loss = test(netGlobal, criterion, test_loader_global)
      print(f'Epoch: {epoch+1}',f'Accuracy: {accuracy}', f'Loss: {loss}')
    print('Training Time (minutes):' + str((time()-time0) / 60))

    accuracy, loss = test(netGlobal, criterion, test_loader_global)
    print(f'Accuracy: {accuracy}', f'Loss: {loss}', f'Learning Rate {learning_rate}')

# %%
def aggregrate_models(net_dict, netGlobal, clients): 
    update_state = {}
    first = True
    for k in clients:
        for key in net_dict[k].state_dict().keys():
            if first:
                update_state[key] = net_dict[k].state_dict()[key]
            else:
                update_state[key] += net_dict[k].state_dict()[key]
        first = False
    for key in update_state:
        update_state[key] = update_state[key] / len(clients)

    netGlobal.load_state_dict(update_state)
    return netGlobal

# %%
mainFL()
# Out:
# Before training : Accuracy: 3.8461538461538463 Loss: 1070.9840257167816 Client 1
# After training : Accuracy: 82.38461538461539 Loss: 506.0436598062515 Client 1
# Before training : Accuracy: 3.8461538461538463 Loss: 1071.0752549171448 Client 2
# After training : Accuracy: 81.08653846153845 Loss: 535.4617659449577 Client 2
# Before training : Accuracy: 3.8461538461538463 Loss: 1070.7932143211365 Client 3
# After training : Accuracy: 82.42788461538461 Loss: 506.3175006210804 Client 3
# Before training : Accuracy: 3.8461538461538463 Loss: 1071.606420993805 Client 4
# After training : Accuracy: 82.19711538461539 Loss: 632.2406592071056 Client 4
# Before training : Accuracy: 3.8461538461538463 Loss: 1070.7001214027405 Client 5
# After training : Accuracy: 80.63942307692308 Loss: 491.03984984755516 Client 5
# Epoch: 1 Accuracy: 3.8461538461538463 Loss: 1070.5067250728607
# Before training : Accuracy: 3.8461538461538463 Loss: 1070.506716966629 Client 1
# After training : Accuracy: 76.73076923076924 Loss: 869.1581445336342 Client 1
# Before training : Accuracy: 3.8461538461538463 Loss: 1070.5067224502563 Client 2
# After training : Accuracy: 77.66826923076923 Loss: 831.4678838253021 Client 2
# Before training : Accuracy: 3.8461538461538463 Loss: 1070.5067148208618 Client 3
# After training : Accuracy: 77.39903846153847 Loss: 926.0393315553665 Client 3
# Before training : Accuracy: 3.8461538461538463 Loss: 1070.5067174434662 Client 4
# After training : Accuracy: 78.91826923076923 Loss: 840.7228745818138 Client 4
# Before training : Accuracy: 3.8461538461538463 Loss: 1070.5067019462585 Client 5
# After training : Accuracy: 79.125 Loss: 859.4729580879211 Client 5
# Epoch: 2 Accuracy: 32.90865384615385 Loss: 987.3965029716492
# Before training : Accuracy: 32.90865384615385 Loss: 987.3964991569519 Client 1
# After training : Accuracy: 82.14903846153845 Loss: 781.5906740427017 Client 1
# Before training : Accuracy: 32.90865384615385 Loss: 987.3965029716492 Client 2
# After training : Accuracy: 82.57211538461539 Loss: 750.8690521717072 Client 2
# Before training : Accuracy: 32.90865384615385 Loss: 987.3964941501617 Client 3
# After training : Accuracy: 82.9951923076923 Loss: 707.188328564167 Client 3
# Before training : Accuracy: 32.90865384615385 Loss: 987.3964948654175 Client 4
# After training : Accuracy: 82.94711538461539 Loss: 749.5586979836226 Client 4
# Before training : Accuracy: 32.90865384615385 Loss: 987.3964967727661 Client 5
# After training : Accuracy: 81.90384615384615 Loss: 767.0354374945164 Client 5
# Epoch: 3 Accuracy: 84.32692307692308 Loss: 633.0014720261097
# Before training : Accuracy: 84.32692307692308 Loss: 633.0014774948359 Client 1
# After training : Accuracy: 81.78365384615385 Loss: 865.0915865004063 Client 1
# Before training : Accuracy: 84.32692307692308 Loss: 633.0014742016792 Client 2
# After training : Accuracy: 83.35576923076923 Loss: 802.1887589991093 Client 2
# Before training : Accuracy: 84.32692307692308 Loss: 633.001478433609 Client 3
# After training : Accuracy: 84.1875 Loss: 890.2676174491644 Client 3
# Before training : Accuracy: 84.32692307692308 Loss: 633.001471310854 Client 4
# After training : Accuracy: 84.8125 Loss: 812.8466759324074 Client 4
# Before training : Accuracy: 84.32692307692308 Loss: 633.0014782696962 Client 5
# After training : Accuracy: 83.21634615384616 Loss: 844.9824141710997 Client 5
# Epoch: 4 Accuracy: 85.99038461538461 Loss: 706.0617087632418
# Before training : Accuracy: 85.99038461538461 Loss: 706.0617119371891 Client 1
# After training : Accuracy: 84.46153846153847 Loss: 749.2236571311951 Client 1
# Before training : Accuracy: 85.99038461538461 Loss: 706.06171682477 Client 2
# After training : Accuracy: 84.72115384615385 Loss: 779.8938538134098 Client 2
# Before training : Accuracy: 85.99038461538461 Loss: 706.061711139977 Client 3
# After training : Accuracy: 85.02403846153847 Loss: 813.3976108133793 Client 3
# Before training : Accuracy: 85.99038461538461 Loss: 706.0617095679045 Client 4
# After training : Accuracy: 85.36538461538463 Loss: 738.4460472762585 Client 4
# Before training : Accuracy: 85.99038461538461 Loss: 706.061711832881 Client 5
# After training : Accuracy: 85.50961538461539 Loss: 776.4108083993196 Client 5
# Epoch: 5 Accuracy: 86.5673076923077 Loss: 653.1781308576465
# Before training : Accuracy: 86.5673076923077 Loss: 653.1781413257122 Client 1
# After training : Accuracy: 84.82211538461539 Loss: 858.025912091136 Client 1
# Before training : Accuracy: 86.5673076923077 Loss: 653.1781268268824 Client 2
# After training : Accuracy: 85.28846153846153 Loss: 817.3583108708262 Client 2
# Before training : Accuracy: 86.5673076923077 Loss: 653.1781283840537 Client 3
# After training : Accuracy: 85.27403846153845 Loss: 786.8326782733202 Client 3
# Before training : Accuracy: 86.5673076923077 Loss: 653.1781273782253 Client 4
# After training : Accuracy: 85.02884615384615 Loss: 825.5140888690948 Client 4
# Before training : Accuracy: 86.5673076923077 Loss: 653.1781270653009 Client 5
# After training : Accuracy: 85.40384615384615 Loss: 817.246302112937 Client 5
# Epoch: 6 Accuracy: 86.8173076923077 Loss: 691.6845760047436
# Before training : Accuracy: 86.8173076923077 Loss: 691.684567399323 Client 1
# After training : Accuracy: 85.41826923076923 Loss: 644.5493742972612 Client 1
# Before training : Accuracy: 86.8173076923077 Loss: 691.6845677345991 Client 2
# After training : Accuracy: 85.95673076923077 Loss: 789.6289460361004 Client 2
# Before training : Accuracy: 86.8173076923077 Loss: 691.6845706999302 Client 3
# After training : Accuracy: 85.46153846153847 Loss: 756.2776860296726 Client 3
# Before training : Accuracy: 86.8173076923077 Loss: 691.684562727809 Client 4
# After training : Accuracy: 85.52884615384615 Loss: 816.4727977961302 Client 4
# Before training : Accuracy: 86.8173076923077 Loss: 691.6845690757036 Client 5
# After training : Accuracy: 85.6201923076923 Loss: 849.7061046808958 Client 5
# Epoch: 7 Accuracy: 86.90384615384616 Loss: 639.0389934591949
# Before training : Accuracy: 86.90384615384616 Loss: 639.0389866903424 Client 1
# After training : Accuracy: 85.8173076923077 Loss: 641.386941075325 Client 1
# Before training : Accuracy: 86.90384615384616 Loss: 639.0389957129955 Client 2
# After training : Accuracy: 85.70192307692308 Loss: 856.2028208374977 Client 2
# Before training : Accuracy: 86.90384615384616 Loss: 639.0389834344387 Client 3
# After training : Accuracy: 85.3125 Loss: 755.1900008618832 Client 3
# Before training : Accuracy: 86.90384615384616 Loss: 639.0389895662665 Client 4
# After training : Accuracy: 86.0625 Loss: 721.7071163058281 Client 4
# Before training : Accuracy: 86.90384615384616 Loss: 639.0389883294702 Client 5
# After training : Accuracy: 85.91826923076923 Loss: 722.0797164291143 Client 5
# Epoch: 8 Accuracy: 87.16826923076924 Loss: 620.2137520387769
# Before training : Accuracy: 87.16826923076924 Loss: 620.2137451209128 Client 1
# After training : Accuracy: 85.95192307692308 Loss: 806.4297197684646 Client 1
# Before training : Accuracy: 87.16826923076924 Loss: 620.2137522548437 Client 2
# After training : Accuracy: 86.0673076923077 Loss: 697.3557882905006 Client 2
# Before training : Accuracy: 87.16826923076924 Loss: 620.2137470543385 Client 3
# After training : Accuracy: 86.02884615384615 Loss: 786.0523974895477 Client 3
# Before training : Accuracy: 87.16826923076924 Loss: 620.213750988245 Client 4
# After training : Accuracy: 86.17788461538461 Loss: 684.4662743359804 Client 4
# Before training : Accuracy: 87.16826923076924 Loss: 620.2137430310249 Client 5
# After training : Accuracy: 85.91346153846153 Loss: 766.6736753061414 Client 5
# Epoch: 9 Accuracy: 87.11057692307692 Loss: 639.402445808053
# Before training : Accuracy: 87.11057692307692 Loss: 639.4024402499199 Client 1
# After training : Accuracy: 86.26923076923076 Loss: 784.8148079514503 Client 1
# Before training : Accuracy: 87.11057692307692 Loss: 639.4024413898587 Client 2
# After training : Accuracy: 86.17307692307692 Loss: 714.1789254844189 Client 2
# Before training : Accuracy: 87.11057692307692 Loss: 639.4024411290884 Client 3
# After training : Accuracy: 86.38942307692308 Loss: 677.0293243527412 Client 3
# Before training : Accuracy: 87.11057692307692 Loss: 639.4024388045073 Client 4
# After training : Accuracy: 85.91346153846153 Loss: 753.3525715470314 Client 4
# Before training : Accuracy: 87.11057692307692 Loss: 639.402442317456 Client 5
# After training : Accuracy: 85.76442307692308 Loss: 771.1445134282112 Client 5
# Epoch: 10 Accuracy: 87.29326923076923 Loss: 616.1288212090731
# Training Time (minutes):22.737429849306743
# Accuracy: 87.29326923076923 Loss: 616.1288263425231 Learning Rate 0.001

# %%
mainFL()
# Out:
# Before training : Accuracy: 11.24 Loss: 360.690372467041 Client 1
# Epoch: 0 Accuracy: 82.13000000000001 Loss: 304.992103099823 Client 1
# Epoch: 1 Accuracy: 84.61999999999999 Loss: 288.37187081575394 Client 1
# Epoch: 2 Accuracy: 86.26 Loss: 270.81847101449966 Client 1
# Epoch: 3 Accuracy: 86.67 Loss: 269.927990347147 Client 1
# Epoch: 4 Accuracy: 87.16000000000001 Loss: 271.3692548274994 Client 1
# Training Time Client 1(minutes):0.45500451723734536
# Before training : Accuracy: 8.92 Loss: 362.83163142204285 Client 2
# Epoch: 0 Accuracy: 82.67 Loss: 168.7133373916149 Client 2
# Epoch: 1 Accuracy: 85.39999999999999 Loss: 178.9130053371191 Client 2
# Epoch: 2 Accuracy: 86.99 Loss: 169.8560634702444 Client 2
# Epoch: 3 Accuracy: 87.16000000000001 Loss: 162.81113712489605 Client 2
# Epoch: 4 Accuracy: 87.3 Loss: 169.29479610919952 Client 2
# Training Time Client 2(minutes):0.46853724320729573
# Before training : Accuracy: 7.59 Loss: 363.7604441642761 Client 3
# Epoch: 0 Accuracy: 73.11999999999999 Loss: 748.6720414161682 Client 3
# Epoch: 1 Accuracy: 75.51 Loss: 717.1181461811066 Client 3
# Epoch: 2 Accuracy: 76.61 Loss: 683.4480540752411 Client 3
# Epoch: 3 Accuracy: 77.25999999999999 Loss: 729.0443053245544 Client 3
# Epoch: 4 Accuracy: 77.3 Loss: 736.6529552936554 Client 3
# Training Time Client 3(minutes):0.43682914574941
# Before training : Accuracy: 8.68 Loss: 369.65344071388245 Client 4
# Epoch: 0 Accuracy: 83.00999999999999 Loss: 249.20343086123466 Client 4
# Epoch: 1 Accuracy: 85.05 Loss: 225.54537534713745 Client 4
# Epoch: 2 Accuracy: 86.64 Loss: 212.7083711270243 Client 4
# Epoch: 3 Accuracy: 86.82 Loss: 182.02119658887386 Client 4
# Epoch: 4 Accuracy: 87.38 Loss: 189.32120324671268 Client 4
# Training Time Client 4(minutes):0.4686561663945516
# Before training : Accuracy: 9.01 Loss: 362.21814727783203 Client 5
# Epoch: 0 Accuracy: 81.98 Loss: 286.65155005455017 Client 5
# Epoch: 1 Accuracy: 85.21 Loss: 227.91628804802895 Client 5
# Epoch: 2 Accuracy: 85.56 Loss: 213.07041666656733 Client 5
# Epoch: 3 Accuracy: 86.98 Loss: 208.08496095240116 Client 5
# Epoch: 4 Accuracy: 87.12 Loss: 215.8257385790348 Client 5
# Training Time Client 5(minutes):0.4535093386967977
